# %% [markdown]
# Bibliotecas

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ---

# %% [markdown]
# Importando Arquivos

# %%
df_ag_econ = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\AgentesEconomicosRegulares.csv', encoding='latin1', sep=';')
df_apoio_fest= pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ApoioFestivaisLaboratoriosWorkshops.csv', encoding='latin1', sep=';')
df_ativi_econ_agent_regis = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\AtividadesEconomicasDosAgentesRegistrados.csv', encoding='latin1', sep=';')
df_bilheteria = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\BilheteriaObrasSemana.csv', encoding='latin1', sep=';')
df_canais_regis = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\CanaisDasProgramadorasRegistradas.csv', encoding='latin1', sep=';')
df_canal_distrib_obrig = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\CanaisDeDistribuicaoObrigatoria.csv', encoding='latin1', sep=';')
df_dir_publi_br = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\DiretoresDeObrasNaoPublicitariasBrasileiras.csv', encoding='latin1', sep=';')

data1 = []
with open('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\DiretoresDeObrasNaoPublicitariasEstrangeiras.csv', 'r', encoding='latin1') as file:
    reader = csv.reader(file, delimiter=';')
    for row in reader:
        data1.append(row)

df_dir_obra_publi_estrang = pd.DataFrame(data1)

df_film_estrang = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\FilmagemEstrangeira.csv', encoding='latin1', sep=';')
df_grupos_econ = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\GruposEconomicos.csv', encoding='latin1', sep=';')
df_invest_proj_renun_fiscal = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\InvestidoresEmProjetosRenunciaFiscal.csv', encoding='latin1', sep=';')
df_obra_nao_publi_br = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ObrasNaoPublicitariasBrasileiras.csv', encoding='latin1', sep=';')
df_obra_n_publi_br_invest_indi = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ObrasNaoPublicitariasBrasileirasComFomentoIndireto.csv', encoding='latin1', sep=';')
df_obra_n_publi_br_fsa = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ObrasNaoPublicitariasBrasileirasComInvestimentoFSA.csv', encoding='latin1', sep=';')

data2 = []
with open('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ObrasNaoPublicitariasEstrangeiras.csv', 'r', encoding='latin1') as file:
    reader = csv.reader(file, delimiter=';')
    for row in reader:
        data2.append(row)

df_obra_publi_estrang = pd.DataFrame(data2)

df_pais_obras_nao_publi_br = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\PaisesDeOrigemObrasNaoPublicitariasBrasileiras.csv', encoding='latin1', sep=';')
df_prg_apoio_mercado = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ProgramaApoioAMercados.csv', encoding='latin1', sep=';')
df_proj_fsa_desemb = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ProjetosContratadosFSAeDesembolso.csv', encoding='latin1', sep=';')
df_proj_renun_fisc = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\ProjetosRenunciaFiscal.csv', encoding='latin1', sep=';')
df_salas_exib = pd.read_csv('C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\banco\\arquivo_original.csv\\SalasDeExibicaoEComplexos.csv', encoding='latin1', sep=';')

# %% [markdown]
# ---

# %% [markdown]
# # Transformação

# %% [markdown]
# Limpeza, Filtragem e Padronização dos Dados

# %% [markdown]
# AgentesEconomicosRegulares

# %%
# Transformando dtypes de colunas

# 'DATA_REGISTRO' em Datetime
df_ag_econ['DATA_REGISTRO'] = pd.to_datetime(df_ag_econ['DATA_REGISTRO'], format='%d/%m/%Y')


# Preenchendo valores vazios

null_values = []
default_value = 3550308.0

for index, row in df_ag_econ.iterrows():
    if pd.isnull(row['CD_MUNICIPIO_IBGE']):
        row['CD_MUNICIPIO_IBGE'] = default_value
        null_values.append(index)

df_ag_econ['CD_MUNICIPIO_IBGE'].fillna(default_value, inplace=True)

# %% [markdown]
# ApoioFestivaisLaboratoriosWorkshops

# %%
# Função para preencher valores nulos específicos
def fill_nan(column, row, new_value):
    df_apoio_fest.at[row, column] = new_value

# Função para padronizar strings específicas
def padro_str(valores, coluna):
    return coluna.replace(valores)
# Aplicar a função para substituir valores 
# coluna = padro_str(valores, coluna)

# Transformando dtypes de colunas

# 'DT_INICIO_FESTIVAL' e 'DT_TERMINO_FESTIVAL' em Datetime
df_apoio_fest['DT_INICIO_FESTIVAL']= pd.to_datetime(df_apoio_fest['DT_INICIO_FESTIVAL'], format='%d/%m/%Y', dayfirst=True)
df_apoio_fest['DT_TERMINO_FESTIVAL']= pd.to_datetime(df_apoio_fest['DT_TERMINO_FESTIVAL'], format='%d/%m/%Y', dayfirst=True)


# 'VALOR_APOIO' em float
df_apoio_fest['VALOR_APOIO'] = df_apoio_fest['VALOR_APOIO'].apply(lambda x: float(x.replace(',', '.')))


# Tratando valores NULOS

# 'MOSTRA_CATEGORIA' 
df_apoio_fest['MOSTRA_CATEGORIA'].fillna("Sem Informação", inplace=True)

# 'CNPJ_PRODUTORA' 
df_apoio_fest['CNPJ_PRODUTORA'].fillna("00.000.000/0000-00", inplace=True)

# 'RAZAO_SOCIAL_PRODUTORA'
fill_nan('RAZAO_SOCIAL_PRODUTORA', 4, 'Daniel Lentini Faria')
fill_nan('RAZAO_SOCIAL_PRODUTORA', 19, 'Maria Julia Pereira de Paiva')
fill_nan('RAZAO_SOCIAL_PRODUTORA', 29, 'Letícia Fudissaku')
fill_nan('RAZAO_SOCIAL_PRODUTORA', 39, 'Mariana Jaspe de Souza Oliveira')
fill_nan('RAZAO_SOCIAL_PRODUTORA', 68, 'Julia Araújo Ferreira da Silva')

# 'METRAGEM'
fill_nan('METRAGEM', 83, 'Média')


# Padronizando Strings

# 'MOSTRA_CATEGORIA'
valores_substituir_metragem = {
    'Mèdia': 'Média',
    'Média ': 'Média',
    ' Mèdia ': 'Média',
    'projeto': 'Projeto de Longa',
    'projeto ': 'Projeto de Longa',
    'Projeto ': 'Projeto de Longa',
    'Projeto': 'Projeto de Longa',
    ' Mêdia ': 'Média',
    'Longa ': 'Longa',
    'Curta ': 'Curta',
    'projeto de longa': 'Projeto de Longa',
    'projeto de longa ': 'Projeto de Longa',
    'projeto de longa  ': 'Projeto de Longa',
    'projeto de Longa': 'Projeto de Longa',
    ' projeto de longa  ': 'Projeto de Longa',
    'Projeto de longa': 'Projeto de Longa',
    'Projeto de longa ': 'Projeto de Longa',
    'Projeto de Longa': 'Projeto de Longa'
}

df_apoio_fest['METRAGEM'] = df_apoio_fest['METRAGEM'].replace(valores_substituir_metragem)

# 'TIPO_APOIO'
valores_substituir_tipo_apoio = {
    'Apoio financeiro' : 'Apoio Financeiro',
    '3. Apoio financeiro ' : 'Apoio Financeiro',
    '3. Apoio financeiro' : 'Apoio Financeiro',
    '3. apoio financeiro ' : 'Apoio Financeiro',
    '1. Cópia 2. Envio 3. Apoio financeiro' : 'Apoio Financeiro',
}

df_apoio_fest['TIPO_APOIO'] = df_apoio_fest['TIPO_APOIO'].replace(valores_substituir_tipo_apoio)


# Padronizando coluna 'MOSTRA_CATEGORIA'
df_apoio_fest['MOSTRA_CATEGORIA'] = df_apoio_fest['nova'] = df_apoio_fest['MOSTRA_CATEGORIA'].str.split(';')
df_apoio_fest = df_apoio_fest.explode('MOSTRA_CATEGORIA')
del df_apoio_fest['nova']

# %% [markdown]
# BilheteriaObrasSemana

# %%
# Transformando dtypes de colunas

# 'ANO_CINEMATOGRAFICO', 'DT_INICIO_EXIBICAO' e 'DT_FIM_EXIBICAO' em Datetime
df_bilheteria['ANO_CINEMATOGRAFICO'] = pd.to_datetime(df_bilheteria['ANO_CINEMATOGRAFICO'], format='ISO8601', dayfirst=True)
df_bilheteria['DT_INICIO_EXIBICAO'] = pd.to_datetime(df_bilheteria['DT_INICIO_EXIBICAO'], format='%d/%m/%Y', dayfirst=True)
df_bilheteria['DT_FIM_EXIBICAO'] = pd. to_datetime(df_bilheteria['DT_FIM_EXIBICAO'], format='%d/%m/%Y', dayfirst=True)

# 'RENDA' em float
df_bilheteria['RENDA'] = df_bilheteria['RENDA'].str.replace(',' , '.').astype(float)

# Preenchendo valores Nulos
df_bilheteria['TITULO_BRASILEIRO'].fillna(df_bilheteria['TITULO_ORIGINAL'], inplace=True)

# %% [markdown]
# CanaisDasProgramadorasRegistradas

# %%
#Verificar se há algum NaN ou Null

def null(df):
    df.info()

#Tratando valores nulos

def fill_null(df, coluna, fill):
    df[coluna].fillna(fill, inplace=True)
    

# Transformando dtypes de colunas

# 'DATA_INICIO_OFERTA' em datetime

def date(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)

# 'NR_IDENTIFICACAO' em float

def convert_to_float(df, column_name):
    df[column_name] = pd.to_numeric(df[column_name].str.strip(), errors='coerce')


fill_null(df_canais_regis, 'CNPJ_PROGRAMADORA', '00.000.000/0000-00')
fill_null(df_canais_regis,'CLASSIFICAO_PROGRAMADORA', 'Sem Informação')
date(df_canais_regis, 'DATA_INICIO_OFERTA')
convert_to_float(df_canais_regis, 'NR_IDENTIFICACAO')

# %% [markdown]
# CanaisDeDistribuicaoObrigatoria

# %%
#Fill Null
def fill_null(df, coluna, fill):
    df[coluna].fillna(fill, inplace=True)

fill_null(df_canal_distrib_obrig, 'CLASSIFICACAO_CANAL', 'SEM INFORMAÇÃO')
fill_null(df_canal_distrib_obrig, 'TIPO_CONTEUDO_CANAL', 'SEM INFORMAÇÃO')
fill_null(df_canal_distrib_obrig, 'CLASSIFICAO_PROGRAMADORA', 'SEM INFORMAÇÃO')

#convert values
def convert_to(df, coluna):
    df[coluna] = df[coluna].astype(float)

convert_to(df_canal_distrib_obrig, 'NR_IDENTIFICACAO')

#to_datetime
def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)

to_datetime(df_canal_distrib_obrig, 'DATA_INICIO_OFERTA')

# %% [markdown]
# DiretoresDeObrasNaoPublicitariasEstrangeiras

# %%
#Fill Null
def fill_null(df, coluna, fill):
    df[coluna].fillna(fill, inplace=True)

fill_null(df_dir_obra_publi_estrang, 3, '.')
fill_null(df_dir_obra_publi_estrang, 4, '.')


def remove_column(df, coluna):
    if coluna in df.columns:
        df.drop(coluna, axis=1, inplace=True)

    else:
        pass

remove_column(df_dir_obra_publi_estrang, 8)
remove_column(df_dir_obra_publi_estrang, 7)
remove_column(df_dir_obra_publi_estrang, 6)
remove_column(df_dir_obra_publi_estrang, 5)

df_dir_obra_publi_estrang.columns = df_dir_obra_publi_estrang.iloc[0]
df_dir_obra_publi_estrang = df_dir_obra_publi_estrang[1:]

df_dir_obra_publi_estrang = df_dir_obra_publi_estrang.drop(df_dir_obra_publi_estrang.columns[0], axis=1)

# %% [markdown]
# FilmagemEstrangeira

# %%
#Preenchendo valores nulos
def fill_null(df, coluna, fill=False):
    df[coluna].fillna(fill, inplace=True)
fill_coluna_tecnicos = df_film_estrang['TOTAL_TECNCIOS_ESTRANGEIROS'].mean()
# fill_coluna_periodo_producao_inicio =
fill_null(df_film_estrang, 'TOTAL_TECNCIOS_ESTRANGEIROS', fill_coluna_tecnicos)

#Trnsformando em int
def convert_to_int(df, column_name):
    df[column_name] = pd.to_numeric(df[column_name], errors='coerce')
    df[column_name].fillna(pd.NA, inplace=True)
    df[column_name] = df[column_name].round().astype('Int64')
convert_to_int(df_film_estrang, 'TOTAL_TECNCIOS_ESTRANGEIROS')

#Corrigindo nome de coluna
def rename_column(df, nome_antigo, nome_novo):
    df.rename(columns={nome_antigo: nome_novo}, inplace=True)

rename_column(df_film_estrang, 'TOTAL_TECNCIOS_ESTRANGEIROS', 'TOTAL_TECNICOS_ESTRANGEIROS')

#Dividindo coluna em 2 e convertendo para datetime
def split_column(df, source_column, new_column1, new_column2, separator):
    df[[new_column1, new_column2]] = df[source_column].str.split(separator, expand=True)

def column_to_datetime(df, new_column):
    df[new_column] = pd.to_datetime(df[new_column], dayfirst=True, errors='coerce')


split_column(df_film_estrang, 'PERIODO_PRODUCAO', 'PERIODO_PRODUCAO_INICIO', 'PERIODO_PRODUCAO_FIM', 'a' )
column_to_datetime(df_film_estrang,'PERIODO_PRODUCAO_INICIO')
column_to_datetime(df_film_estrang,'PERIODO_PRODUCAO_FIM')
column_to_datetime(df_film_estrang,'DT_APROVACAO')

df_film_estrang = df_film_estrang.drop(columns=['PERIODO_PRODUCAO'])

df_film_estrang.loc[22, 'PERIODO_PRODUCAO_FIM'] = pd.to_datetime('2020-02-15')

df_film_estrang.dropna(inplace=True)

# %% [markdown]
# InvestidoresEmProjetosRenunciaFiscal

# %%
colunas = ['ART25', 'ART18', 'ART1A', 'ART1', 'ART39', 'ART3A', 'ART3', 'ART41', 'VL_TOTAL_INVESTIDO']
def col_convert(df, colunas,old, new, type):
    for colunas in df[colunas]:
        if df[colunas].dtype == object:
            df[colunas] = df[colunas].str.replace(old, new).astype(float)

col_convert(df_invest_proj_renun_fiscal, colunas, ',', '.', float)

# %% [markdown]
# ObrasNaoPublicitariasBrasileiras

# %%
#'QUANTIDAE_EPISODIOS'
#Preenchendo valores nulos
def fill_null(df, coluna, value):
    df[coluna].fillna(value, inplace=True)

fill_null(df_obra_nao_publi_br, 'QUANTIDADE_EPISODIOS', 1)
df_obra_nao_publi_br['QUANTIDADE_EPISODIOS'] = df_obra_nao_publi_br['QUANTIDADE_EPISODIOS'].round().astype('int64')


#'SUBTIPO_OBRA'
#Replace em valores
def replace(df,coluna,old_value, value):
    df[coluna].replace(old_value, value, inplace=True)
   
replace(df_obra_nao_publi_br,'SUBTIPO_OBRA', '                                                                                                    ', 'NÃO INFORMADO')
replace(df_obra_nao_publi_br,'SUBTIPO_OBRA', 'NÃO INFORMADO                                                                                       ', 'NÃO INFORMADO')


#'ANO_PRODUCAO' e 'DT_EMISSAO_CPB'
#convert to datetime
def convert_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')

def coluna_to_datetime(df, old_col, new_col):
    df[new_col] = df[old_col].str.extract(r'(\d{4})')
    df[new_col] = pd.to_datetime(df[new_col], format='%Y', errors='coerce')
    df = df.drop(columns=[old_col])

coluna_to_datetime(df_obra_nao_publi_br, 'ANO_PRODUCAO', 'ANO_PRODUCAO')

#Valores Nulos
df_obra_nao_publi_br = df_obra_nao_publi_br.dropna(subset=['ANO_PRODUCAO'])
convert_datetime(df_obra_nao_publi_br, 'DT_EMISSAO_CPB')

# %% [markdown]
# ObrasNaoPublicitariasEstrangeiras

# %%
#Fill Null
def remove_column(df, coluna):
    if coluna in df.columns:
        df.drop(coluna, axis=1, inplace=True)

    else:
        pass

remove_column(df_obra_publi_estrang, 11)
remove_column(df_obra_publi_estrang, 12)

df_obra_publi_estrang.columns = df_obra_publi_estrang.iloc[0]
df_obra_publi_estrang = df_obra_publi_estrang[1:]

def convert_to(df, coluna):
    mask = df[coluna].str.contains('A', na=False)
    df[coluna] = pd.to_datetime(df[coluna], format='mixed', dayfirst=True, errors='coerce')
    df[coluna] = df[coluna].where(~mask, pd.NaT)

convert_to(df_obra_publi_estrang, 'DT_EMISSAO_ROE')
convert_to(df_obra_publi_estrang, 'ANO_PRODUCAO')

df_obra_publi_estrang['ANO_PRODUCAO'].fillna('2016-01-01', inplace=True)

df_obra_publi_estrang.dropna(inplace=True)

#'SUBTIPO_OBRA'
#Replace em valores
def replace(df,coluna,old_value, value):
    df[coluna].replace(old_value, value, inplace=True)
   
replace(df_obra_publi_estrang,'SUB_TIPO_OBRA', '                                                                                                    ', 'NÃO INFORMADO')
replace(df_obra_publi_estrang,'SUB_TIPO_OBRA', '', 'NÃO INFORMADO')
replace(df_obra_publi_estrang,'SUB_TIPO_OBRA', 'NÃO INFORMADO                                                                                       ', 'NÃO INFORMADO')

# %% [markdown]
# ProgramaApoioAMercados

# %%
#to_datetime
def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')

#to float
def convert_to_float(df, coluna):
    df[coluna] = df[coluna].apply(lambda x: float(x.replace(',','.')))

convert_to_float(df_prg_apoio_mercado, 'VALOR_APOIO_FINANCEIRO')
to_datetime(df_prg_apoio_mercado, 'DT_INICIO_EVENTO')
to_datetime(df_prg_apoio_mercado, 'DT_TERMINO_EVENTO')

# %% [markdown]
# ProjetosContratadosFSAeDesembolso

# %%
# Tratando valores nulos
def fill_null(df, coluna, fill):
    df[coluna].fillna(fill, inplace=True)

# fill_null(df_proj_fsa_desemb, 'TITULO_PROJETO', 'NÃO FILME')
fill_null(df_proj_fsa_desemb, 'CNPJ_PRODUTORA', 'SEM PRODUTORA')
fill_null(df_proj_fsa_desemb, 'RAZAO_SOCIAL_PRODUTORA', 'SEM PRODUTORA')
fill_null(df_proj_fsa_desemb, 'CNPJ_DISTRIBUIDORA_PROGRAMADORA', 'SEM DISTRIBUIDORA/PROGRAMADORA')
fill_null(df_proj_fsa_desemb, 'RAZAO_SOCIAL_DISTRIBUIDORA_PROGRAMADORA', 'SEM DISTRIBUIDORA/PROGRAMADORA')
fill_null(df_proj_fsa_desemb, 'DT_PRIMEIRO_DESEMBOLSO', 'SEM DESEMBOLSO')

# to_datetime
def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')

to_datetime(df_proj_fsa_desemb, 'DT_PUBLICACAO_CONTRATO_DOU')
#to_datetime(df_proj_fsa_desemb, 'DT_PRIMEIRO_DESEMBOLSO')

# Float
def convert_to_float(df, coluna):
    df[coluna] = df[coluna].apply(lambda x: float(str(x).replace(',', '.')) if isinstance(x, (str, float)) else x)

convert_to_float(df_proj_fsa_desemb, 'VL_CONTRATO_DOU')
convert_to_float(df_proj_fsa_desemb, 'VL_TOTAL_LIBERADO')

# to replace
def replace(df, coluna, old_value, new_value):
    df[coluna].replace(old_value, new_value, inplace=True)

replace(df_proj_fsa_desemb, 'ANO_CHAMADA_PUBLICA', '2017/2018', 2017)
replace(df_proj_fsa_desemb, 'ANO_CHAMADA_PUBLICA', '2017/2018/2018', 2017)

df_proj_fsa_desemb['ANO_CHAMADA_PUBLICA'] = pd.to_datetime(df_proj_fsa_desemb['ANO_CHAMADA_PUBLICA'], format='%Y').dt.year
fill_null(df_proj_fsa_desemb, 'VL_TOTAL_LIBERADO', 0)

df_proj_fsa_desemb
#--------------------------


def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')

to_datetime(df_proj_fsa_desemb, 'DT_PRIMEIRO_DESEMBOLSO')

def to_datetime_b(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna],format='%Y')

to_datetime_b(df_proj_fsa_desemb, 'ANO_CHAMADA_PUBLICA')


def to_datetime_c(df, coluna, date_format):
    df[coluna] = pd.to_datetime(df[coluna], format=date_format)

to_datetime_c(df_proj_fsa_desemb, 'DT_PUBLICACAO_CONTRATO_DOU', '%Y-%m-%d')

#Preenchendo valores nulos na copluna DT_PRIMEIRO_DESEMBOLSO com a média = 37 dias

df_proj_fsa_desemb_time = df_proj_fsa_desemb.dropna()
df_proj_fsa_desemb_time['TEMPO_DESEMBOLSO'] = df_proj_fsa_desemb['DT_PUBLICACAO_CONTRATO_DOU'] - df_proj_fsa_desemb['DT_PRIMEIRO_DESEMBOLSO']
mean = df_proj_fsa_desemb_time['TEMPO_DESEMBOLSO'].mean()

def to_datetime_a(df, coluna,coluna2):
    df[coluna] = df[coluna].fillna(pd.to_datetime(df[coluna2])+ pd.DateOffset(day=37))

to_datetime_a(df_proj_fsa_desemb, 'DT_PRIMEIRO_DESEMBOLSO', 'DT_PUBLICACAO_CONTRATO_DOU')
# Out:
# C:\Users\syafo\AppData\Local\Temp\ipykernel_7212\971991900.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_proj_fsa_desemb_time['TEMPO_DESEMBOLSO'] = df_proj_fsa_desemb['DT_PUBLICACAO_CONTRATO_DOU'] - df_proj_fsa_desemb['DT_PRIMEIRO_DESEMBOLSO']
# C:\Users\syafo\AppData\Local\Temp\ipykernel_7212\971991900.py:63: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex.
#   df[coluna] = df[coluna].fillna(pd.to_datetime(df[coluna2])+ pd.DateOffset(day=37))

# %% [markdown]
# ProjetosRenunciaFiscal

# %%
def convert_to_float(df, colunas):
    df[colunas] = df[colunas].replace(',', '.', regex=True).astype(float)

cols_to_convert = ['LEI_8313', 'ART1', 'ART1A', 'ART3', 'ART3A', 'ART39', 'FUNCINES', 'TOTAL_CAPTADO']
convert_to_float(df_proj_renun_fisc, cols_to_convert)

def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], format='%d/%m/%Y', errors='coerce')

to_datetime(df_proj_renun_fisc, 'DT_APROVACAO_CAPTACAO')
to_datetime(df_proj_renun_fisc, 'DT_1_LIBERACAO')



def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)

to_datetime(df_proj_renun_fisc, 'DT_1_LIBERACAO')
to_datetime(df_proj_renun_fisc, 'DT_APROVACAO_CAPTACAO')

def to_datetime_b(df, coluna):
    df['ANO_APROVACAO'] = pd.to_datetime(df[coluna],format='%Y-%m-%d').dt.year


to_datetime_b(df_proj_renun_fisc, 'DT_APROVACAO_CAPTACAO')

# %% [markdown]
# SalasDeExibicaoEComplexos

# %%
#Fill Null
def fill_null(df, coluna, fill):
    df[coluna].fillna(fill, inplace=True)

fill_null(df_salas_exib, 'NOME_SALA', 'SEM INFORMAÇÃO')
fill_null(df_salas_exib, 'REGISTRO_SALA', 0)
fill_null(df_salas_exib, 'SITUACAO_SALA', 'SEM INFORMAÇÃO')
fill_null(df_salas_exib, 'ASSENTOS_SALA', 177)
fill_null(df_salas_exib, 'PAGINA_ELETRONICA_COMPLEXO', 'SEM INFORMAÇÃO')
fill_null(df_salas_exib, 'ENDERECO_COMPLEXO', 'SEM INFORMAÇÃO')
fill_null(df_salas_exib, 'NUMERO_ENDERECO_COMPLEXO', 0)
fill_null(df_salas_exib, 'COMPLEMENTO_COMPLEXO', 0)
fill_null(df_salas_exib, 'BAIRRO_COMPLEXO', 'SEM_INFORMAÇÃO')
fill_null(df_salas_exib, 'MUNICIPIO_COMPLEXO', 'SEM_INFORMAÇÃO')
fill_null(df_salas_exib, 'UF_COMPLEXO', 'SEM_INFORMAÇÃO')

#convert type:
def convert_type(df, coluna):
    df[coluna] = df[coluna].astype(int)

convert_type(df_salas_exib, 'REGISTRO_SALA')
convert_type(df_salas_exib, 'ASSENTOS_SALA')
convert_type(df_salas_exib, 'REGISTRO_COMPLEXO')
convert_type(df_salas_exib, 'NUMERO_ENDERECO_COMPLEXO')

# %% [markdown]
# Exportação

# %%
def export(df, file):
    df.to_csv(file, index=False, encoding='utf-8')

export(df_ag_econ, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\AgentesEconomicosRegulares.csv')
export(df_apoio_fest, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ApoioFestivaisLaboratoriosWorkshops.csv')
export(df_ativi_econ_agent_regis, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\AtividadesEconomicasDosAgentesRegistrados.csv')
export(df_bilheteria, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\BilheteriaObrasSemana.csv' )
export(df_canais_regis, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\CanaisDasProgramadorasRegistradas.csv')
export(df_canal_distrib_obrig, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\CanaisDeDistribuicaoObrigatoria.csv')
export(df_dir_publi_br, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\DiretoresDeObrasNaoPublicitariasBrasileiras.csv')
export(df_dir_obra_publi_estrang, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\DiretoresDeObrasNaoPublicitariasEstrangeiras.csv')
export(df_film_estrang, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\FilmagemEstrangeira.csv')
export(df_grupos_econ, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\GruposEconomicos.csv')
export(df_invest_proj_renun_fiscal, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\InvestidoresEmProjetosRenunciaFiscal.csv')
export(df_obra_nao_publi_br, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ObrasNaoPublicitariasBrasileiras.csv')
export(df_obra_n_publi_br_invest_indi, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ObrasNaoPublicitariasBrasileirasComFomentoIndireto.csv')
export(df_obra_n_publi_br_fsa, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ObrasNaoPublicitariasBrasileirasComInvestimentoFSA.csv')
export(df_obra_publi_estrang, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ObrasNaoPublicitariasEstrangeiras.csv')
export(df_pais_obras_nao_publi_br, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\PaisesDeOrigemObrasNaoPublicitariasBrasileiras.csv')
export(df_prg_apoio_mercado, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ProgramaApoioAMercados.csv')
export(df_proj_fsa_desemb, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ProjetosContratadosFSAeDesembolso.csv')
export(df_proj_renun_fisc, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\ProjetosRenunciaFiscal.csv')
export(df_salas_exib, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\Tratamentos\\Tratamento_1\\Tramento_1.csv\\SalasDeExibicaoEComplexos.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## EDA - ANCINE ES

# %%
cnpjs_to_check = [
 '40.222.072/0001-06',
 '49.405.221/0001-39',
 '15.131.165/0001-70',
 '12.301.061/0001-78',
 '10.763.360/0001-07',
 '25.990.290/0001-99',
 '03.425.449/0001-90',
 '15.651.792/0001-31',
 '46.343.097/0001-36',
 '32.177.367/0001-71',
 '35.751.309/0001-06',
 '45.589.940/0001-04',
 '26.421.082/0001-31',
 '32.337.237/0001-59',
 '21.916.610/0001-00',
 '33.753.853/0001-53',
 '32.605.071/0001-04',
 '42.119.387/0001-40',
 '30.013.364/0001-77',
 '03.172.036/0001-40',
 '40.923.297/0001-81',
 '42.701.098/0001-54',
 '43.206.211/0001-98',
 '12.530.623/0001-55',
 '24.575.039/0001-03',
 '05.804.377/0001-17',
 '30.350.510/0001-50',
 '32.558.054/0001-63',
 '03.861.448/0001-98',
 '29.708.938/0001-42',
 '21.351.722/0001-60',
 '34.211.341/0001-28',
 '14.992.876/0001-76',
 '34.107.095/0001-69',
 '24.241.892/0001-80',
 '36.219.247/0001-40',
 '40.226.313/0001-87',
 '42.999.841/0001-02',
 '24.147.907/0001-46',
 '14.210.788/0001-75',
 '16.806.723/0001-12',
 '42.220.837/0001-96',
 '13.546.570/0001-23',
 '49.371.962/0001-46',
 '29.995.994/0001-05',
 '19.962.586/0001-01',
 '19.974.069/0001-44',
 '16.877.661/0001-30',
 '44.537.226/0001-00',
 '33.625.380/0001-09',
 '31.330.222/0001-04',
 '02.616.581/0001-16',
 '32.243.334/0001-82',
 '13.373.053/0001-08',
 '09.385.630/0001-04',
 '42.152.957/0001-01',
 '14.651.453/0001-92',
 '35.862.793/0001-32',
 '04.585.783/0001-73',
 '28.999.862/0001-99',
 '31.478.621/0001-09',
 '10.634.153/0001-44',
 '00.589.339/0001-75',
 '28.298.402/0001-33',
 '37.064.188/0001-41',
 '37.184.804/0001-06',
 '12.476.637/0001-38',
 '30.967.902/0001-62',
 '33.561.124/0001-03',
 '14.985.732/0001-92',
 '00.414.568/0001-59',
 '25.103.064/0001-49',
 '31.529.645/0001-40',
 '35.684.520/0001-45',
 '20.811.009/0001-90',
 '13.380.867/0001-61',
 '44.471.132/0001-77',
 '04.201.181/0001-75',
 '42.856.251/0001-12',
 '03.692.683/0001-83',
 '24.734.932/0001-26',
 '15.693.797/0001-27',
 '08.103.899/0001-80',
 '43.032.269/0001-62',
 '18.589.962/0001-93',
 '09.134.587/0001-04',
 '17.140.796/0001-80',
 '25.912.530/0001-37',
 '11.982.842/0001-02',
 '13.088.643/0001-80',
 '21.710.727/0001-32',
 '32.261.592/0001-91',
 '46.641.605/0001-62',
 '29.116.285/0001-02',
 '29.621.500/0001-22',
 '44.681.987/0001-22',
 '27.065.150/0001-30',
 '34.430.442/0001-90',
 '02.737.078/0001-19',
 '20.533.821/0001-09',
 '39.341.953/0001-59',
 '10.613.523/0001-67',
 '30.553.792/0001-92',
 '26.682.199/0001-79',
 '14.410.301/0001-06',
 '11.136.684/0001-70',
 '34.532.932/0001-05',
 '31.876.653/0001-62',
 '49.039.943/0001-17',
 '17.151.166/0001-01',
 '15.757.699/0001-06',
 '28.921.806/0001-31',
 '09.208.990/0001-22',
 '11.609.242/0001-01',
 '32.290.770/0001-02',
 '27.329.556/0001-82',
 '21.065.201/0001-47',
 '20.518.008/0001-51',
 '12.379.149/0001-02',
 '37.114.074/0001-69',
 '21.443.150/0001-40',
 '49.564.368/0001-71',
 '04.676.620/0001-04',
 '14.165.196/0001-89',
 '16.595.181/0001-86',
 '13.981.640/0001-71',
 '34.941.850/0001-06',
 '08.434.432/0001-12',
 '13.958.660/0001-21',
 '39.794.680/0001-06',
 '44.135.340/0001-03',
 '04.920.643/0001-04',
 '17.195.358/0001-10',
 '18.670.862/0001-97',
 '21.141.011/0001-61',
 '18.580.137/0001-28',
 '31.451.298/0001-80',
 '43.380.531/0001-60',
 '29.611.853/0001-41',
 '29.031.260/0001-06',
 '31.116.435/0001-20',
 '17.727.654/0001-14',
 '14.876.344/0001-73',
 '29.971.842/0001-72',
 '44.447.754/0001-60',
 '24.879.526/0001-51',
 '01.915.175/0001-91',
 '32.992.475/0001-06',
 '17.714.670/0001-72',
 '07.162.196/0001-60',
 '39.741.470/0001-41',
 '14.240.951/0001-42',
 '35.587.888/0001-95',
 '18.162.501/0001-30',
 '26.033.493/0001-50',
 '16.370.907/0001-82',
 '04.769.554/0001-09',
 '20.801.818/0001-10',
 '30.227.228/0001-80',
 '32.719.785/0001-43',
 '09.445.277/0001-00',
 '22.810.678/0001-72',
 '14.635.446/0001-05',
 '42.128.343/0001-86',
 '10.852.692/0001-50',
 '26.671.292/0001-88',
 '31.750.022/0001-00',
 '19.628.647/0001-90',
 '21.033.878/0001-01',
 '32.479.123/0001-43',
 '23.572.489/0001-71',
 '24.381.120/0001-44',
 '31.689.843/0001-70',
 '10.960.415/0001-60',
 '26.089.873/0001-06',
 '00.373.973/0001-76',
 '18.202.976/0001-02',
 '30.428.516/0001-00',
 '21.797.177/0001-30',
 '09.369.796/0001-29',
 '13.318.058/0001-20',
 '27.478.257/0001-00',
 '23.717.729/0001-89',
 '23.923.441/0001-60',
 '27.419.100/0001-03',
 '19.387.261/0001-34',
 '36.565.202/0001-28',
 '13.991.594/0001-91',
 '17.119.823/0001-33',
 '33.378.866/0001-90',
 '08.030.429/0001-33',
 '16.994.240/0001-99',
 '36.049.641/0001-88',
 '06.914.274/0001-72',
 '33.998.771/0001-79',
 '12.354.771/0001-66',
 '26.349.364/0001-75',
 '17.591.225/0001-62',
 '31.458.492/0001-97',
 '31.859.201/0001-72',
 '37.281.569/0001-82',
 '31.449.125/0001-27',
 '34.853.340/0001-87',
 '40.203.694/0001-89',
 '49.129.924/0001-81',
 '39.246.925/0001-52',
 '15.121.862/0001-40',
 '27.585.858/0001-11',
 '14.128.876/0001-22',
 '26.203.415/0001-56',
 '12.663.752/0001-11',
 '03.132.906/0001-58',
 '21.681.140/0001-42',
 '29.821.631/0001-53',
 '18.012.019/0001-13',
 '31.703.432/0001-92',
 '35.220.801/0001-47',
 '28.548.077/0001-10',
 '05.878.063/0001-69',
 '08.427.216/0001-40',
 '22.869.009/0001-76',
 '32.577.562/0001-99',
 '31.639.889/0001-85',
 '43.261.669/0001-40',
 '03.694.276/0001-05',
 '24.890.666/0001-20',
 '20.964.886/0001-09',
 '29.086.297/0001-31',
 '08.101.204/0001-20',
 '18.008.314/0001-04',
 '13.967.089/0001-01',
 '17.652.148/0001-03',
 '11.767.820/0001-20',
 '31.964.490/0001-70',
 '18.391.109/0001-62',
 '46.850.630/0001-56',
 '31.621.283/0001-12',
 '05.077.549/0001-06',
 '28.754.676/0001-90',
 '45.795.915/0001-79',
 '41.303.412/0001-88',
 '33.113.878/0001-92',
 '11.365.117/0001-95',
 '16.649.153/0001-02',
 '10.434.099/0001-93',
 '33.880.406/0001-65',
 '11.144.385/0001-87',
 '39.306.027/0001-42',
 '41.243.402/0001-02',
 '37.893.600/0001-36',
 '04.018.247/0001-96',
 '29.779.707/0001-20',
 '18.086.583/0001-80',
 '42.351.422/0001-51'
]

# %%
#AgentesEconomicosRegulares
df_ag_econ_reg_es = df_ag_econ[df_ag_econ['UF'] == 'ES']

#Removendo CPF da Razão Social

def remove_numbers(razao_social):
    return razao_social[:-11] if razao_social and razao_social[-11:].isdigit() else razao_social

df_ag_econ_reg_es['RAZAO_SOCIAL'] = df_ag_econ_reg_es['RAZAO_SOCIAL'].apply(remove_numbers)

def replace(df, column, old_value, new_value):
    df[column].replace(old_value, new_value, inplace=True)

replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.405.221 FREDERICO DO SACRAMENTO JANUARIO', 'FREDERICO DO SACRAMENTO JANUARIO')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.371.962 TIAGO DOS SANTOS MATHEUS', 'TIAGO DOS SANTOS MATHEUS')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '33.561.124 WILLIAM LEGORA SILVESTRE', 'WILLIAM LEGORA SILVESTRE')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '44.471.132 HERICA SANTOS DUARTE GODOY', 'HERICA SANTOS DUARTE GODOY')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.039.943 SARA DOS SANTOS SILVA ENGELHARDT', 'SARA DOS SANTOS SILVA ENGELHARDT')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.564.368 LARISSA MUNIZ MARANHÃO GUSMÃO', 'LARISSA MUNIZ MARANHÃO GUSMÃO')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '29.971.842 GRASIELLE FINK DA SILVA', 'GRASIELLE FINK DA SILVA')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.129.924 IRINEU CRUZEIRO NETO', 'IRINEU CRUZEIRO NETO')


#------------------------------------------
#ProjetosContratadosFSAeDesembolso
df_proj_fsa_desemb_es = pd.DataFrame(columns=df_proj_fsa_desemb.columns)

for cnpj in cnpjs_to_check:
    matching_rows = df_proj_fsa_desemb[df_proj_fsa_desemb['CNPJ_PROPONENTE'].str.contains(cnpj)]
    df_proj_fsa_desemb_es = pd.concat([df_proj_fsa_desemb_es, matching_rows])

df_proj_fsa_desemb_es.reset_index(drop=True, inplace=True)

# to replace
def replace(df, coluna, old_value, new_value):
    df[coluna].replace(old_value, new_value, inplace=True)

replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 11', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 02', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 03', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 05', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 07', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODECINE 04', 'PRODECINE')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODECINE 05', 'PRODECINE')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODECINE 01', 'PRODECINE')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODAV 05', 'PRODAV')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODAV - TVS PÚBLICAS', 'PRODAV')

df_proj_fsa_desemb_es['VL_CONTRATO_DOU'] = df_proj_fsa_desemb_es['VL_CONTRATO_DOU'].replace(',', '.')
df_proj_fsa_desemb_es['VL_TOTAL_LIBERADO'] = df_proj_fsa_desemb_es['VL_TOTAL_LIBERADO'].replace(',', '.')


#----------------------------
#ProjetosRenunciaFiscal
df_proj_renun_fisc_es = df_proj_renun_fisc[df_proj_renun_fisc['UF_PROPONENTE'] == 'ES']


#------------------------------
#AtividadeEconômicaDosAgentes
df_ativi_econ_agent_regis_es = df_ativi_econ_agent_regis[df_ativi_econ_agent_regis['CNPJ'].apply(lambda x: x in cnpjs_to_check)]


#-------------------------------
#GruposEconômicos
df_grupos_econ_es = df_grupos_econ[df_grupos_econ['CNPJ_EMPRESA'].apply(lambda x: x in cnpjs_to_check)]


#-------------------------------
#SalasDeExibiçãoEComplexos
df_salas_exib_es = df_salas_exib[df_salas_exib['UF_COMPLEXO'] == 'ES']

df_salas_exib_es_end = df_salas_exib_es[['ENDERECO_COMPLEXO',
       'NUMERO_ENDERECO_COMPLEXO', 'COMPLEMENTO_COMPLEXO', 'BAIRRO_COMPLEXO',
       'MUNICIPIO_COMPLEXO', 'CEP_COMPLEXO']]

df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'] = df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'].astype(str)
df_salas_exib_es_end['BAIRRO_COMPLEXO'] = df_salas_exib_es_end['BAIRRO_COMPLEXO'].astype(str)
df_salas_exib_es_end['CEP_COMPLEXO'] = df_salas_exib_es_end['CEP_COMPLEXO'].astype(str)
df_salas_exib_es_end['COMPLEMENTO_COMPLEXO'] = df_salas_exib_es_end['COMPLEMENTO_COMPLEXO'].astype(str)
df_salas_exib_es_end['ENDERECO_COMPLEXO'] = df_salas_exib_es_end['ENDERECO_COMPLEXO'].astype(str)
df_salas_exib_es_end['MUNICIPIO_COMPLEXO'] = df_salas_exib_es_end['MUNICIPIO_COMPLEXO'].astype(str)

df_salas_exib_es_end['ENDERECO_COMPLETO'] = df_salas_exib_es_end['ENDERECO_COMPLEXO'] + ' ' + '- ' + \
                                            df_salas_exib_es_end['COMPLEMENTO_COMPLEXO'] + ' ' + '- N° ' + \
                                            df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'] + ' ' + '- ' + \
                                            df_salas_exib_es_end['BAIRRO_COMPLEXO'] + ' ' + '- CEP:' + \
                                            df_salas_exib_es_end['CEP_COMPLEXO'] + ' ' + '- ' + \
                                            df_salas_exib_es_end['MUNICIPIO_COMPLEXO']

dataframes_to_concat = [df_salas_exib_es, df_salas_exib_es_end[['ENDERECO_COMPLETO']]]
df_salas_exib_es = pd.concat(dataframes_to_concat, axis=1)
# Out:
# C:\Users\syafo\AppData\Local\Temp\ipykernel_7212\4253593748.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ag_econ_reg_es['RAZAO_SOCIAL'] = df_ag_econ_reg_es['RAZAO_SOCIAL'].apply(remove_numbers)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_7212\4253593748.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column].replace(old_value, new_value, inplace=True)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_7212\4253593748.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Adequação Power BI

# %%
#Projetos de Renúncia Fiscal
def replace(df, column):
    df[column] = df[column].astype(str)
    df[column] = df[column].str.replace('.', ',')
    return df

# replace(df_proj_renun_fisc_es, 'TOTAL_CAPTADO')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART1')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART1A')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART3')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART39')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART3A')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'FUNCINES')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'LEI_8313')

# #-----------------------------------------------

#Projetos FSA e Desembolso

# replace(df_proj_fsa_desemb_es, 'VL_CONTRATO_DOU')
# replace(df_proj_fsa_desemb_es, 'VL_TOTAL_LIBERADO')

# #-----------------------------------------------

#Investidores Projetos Renúncia Fiscal

# replace(df_invest_proj_renun_fiscal, 'ART25')
# replace(df_invest_proj_renun_fiscal, 'ART18')
# replace(df_invest_proj_renun_fiscal, 'ART1A')
# replace(df_invest_proj_renun_fiscal, 'ART1')
# replace(df_invest_proj_renun_fiscal, 'ART39')
# replace(df_invest_proj_renun_fiscal, 'ART3A')
# replace(df_invest_proj_renun_fiscal, 'ART3')
# replace(df_invest_proj_renun_fiscal, 'ART41')
# replace(df_invest_proj_renun_fiscal, 'VL_TOTAL_INVESTIDO')

# %% [markdown]
# ### Novos Dataframes

# %%
#Lista de Projetos Aprovados no ES
df_concat_proj_1 = df_proj_fsa_desemb_es[['VL_TOTAL_LIBERADO', 'CNPJ_PROPONENTE', 'TITULO_PROJETO', 'CHAMADA_PUBLICA']]
df_concat_proj_2 = df_proj_renun_fisc_es[['TOTAL_CAPTADO', 'CNPJ_PROPONENTE', 'TITULO_PROJETO']]

df_concat_proj_2 = df_concat_proj_2.rename(columns={'TOTAL_CAPTADO' : 'TOTAL_CAPTADO_RENUN', 'TITULO_PROJETO' : 'TITULO_PROJETO_RENUN' })
df_concat_proj_1 = df_concat_proj_1.rename(columns={'VL_TOTAL_LIBERADO' : 'VL_TOTAL_LIBERADO_FSA_DESEMB', 'TITULO_PROJETO' : 'TITULO_PROJETO_FSA_DESEMB'})

df_projetos_aprov_es = df_concat_proj_1.merge(df_concat_proj_2, on='CNPJ_PROPONENTE', how='outer')

def fillna(df, column):
    df[column].fillna(0.0, inplace=True)

fillna(df_projetos_aprov_es, 'TOTAL_CAPTADO_RENUN')
fillna(df_projetos_aprov_es, 'VL_TOTAL_LIBERADO_FSA_DESEMB')

df_projetos_aprov_es['SOMA_TOTAL_CAPTADO'] = df_projetos_aprov_es['TOTAL_CAPTADO_RENUN'] + df_projetos_aprov_es['VL_TOTAL_LIBERADO_FSA_DESEMB']
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=11)
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=3)
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=23)
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=24)


#------------------------------------------------------------
#Dataframe de Títulos de Projeto
df_titulos_proj = df_projetos_aprov_es[['CNPJ_PROPONENTE', 'TITULO_PROJETO_FSA_DESEMB', 'TITULO_PROJETO_RENUN', 'CHAMADA_PUBLICA']]

def replace(df, column, row, new):
    df.at[row, column] = new

replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 3, 'Outro Sertão')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 11, 'A Incrível Jornada - A História das Baleias Capixabas')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 33, 'HELENA')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 34, 'Punhal')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 35, 'Morte da Mulata (A) - Filme')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 36, 'A Rebelião dos Estudantes      (Ex - Rebelião dos Estudantes - Brasília, 1968 (A))')
replace(df_titulos_proj, 'CHAMADA_PUBLICA', 1, 'PRODAV')
replace(df_titulos_proj, 'CHAMADA_PUBLICA', 28, 'PRODAV')

df_titulos_proj = df_titulos_proj.drop(index=24)
df_titulos_proj = df_titulos_proj.drop(index=23)

df_titulos_proj = df_titulos_proj.rename(columns={'TITULO_PROJETO_FSA_DESEMB' : 'TITULO_PROJETOS_APROVADOS'})
df_titulos_proj = df_titulos_proj[['CNPJ_PROPONENTE', 'TITULO_PROJETOS_APROVADOS', 'CHAMADA_PUBLICA']]

df_titulos_proj['TITULO_PROJETOS_APROVADOS'] = df_titulos_proj['TITULO_PROJETOS_APROVADOS'].fillna(df_titulos_proj['CHAMADA_PUBLICA'][0])

# %% [markdown]
# ### Export ANCINE ES

# %%
def export(df, file):
    df.to_csv(file, index=False, encoding='utf-8', sep=',')

# Export para Test
# export(df, 'arquivo_teste.csv')

# export(df_ag_econ_reg_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_AgentesEconomicosRegulares.csv')
# export(df_proj_fsa_desemb_es , 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_ProjetosContratadosFSAeDesembolso.csv')
# export(df_proj_renun_fisc_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_ProjetosRenunciaFiscal.csv')
# export(df_ativi_econ_agent_regis_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_AtividadesEconomicasDosAgentesRegistrados.csv')
# export(df_grupos_econ_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_GruposEconomicos.csv')
# export(df_salas_exib_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_SalasDeExibicaoEComplexos.csv')

#Dataframe Projetos
# export(df_projetos_aprov_es, 'ProjetosAprovados.csv')
# export(df_titulos_proj, 'TitulosProjetos.csv')
