# %%
import pandas as pd
import numpy as np

# %%
df_film_estrang = pd.read_csv('FilmagemEstrangeira.csv', encoding='latin1', sep=';')
df_film_estrang = df_film_estrang[['TITULO_ORIGINAL', 'PRODUTORA_BRASILEIRA', 'UF_PRODUTORA_BRASILEIRA', 'PRODUTORA_ESTRANGEIRA', 'PAIS_PRODUTORA_ESTRANGEIRA', 'TIPO_OBRA', 'TOTAL_TECNCIOS_ESTRANGEIROS', 'LOCAL_FILMAGEM ']]
new_names = ['TITULO_ORIGINAL', 'PRODUTORA_BRASILEIRA', 'UF_PRODUTORA_BRASILEIRA', 'PRODUTORA_ESTRANGEIRA', 'PAIS_PRODUTORA_ESTRANGEIRA', 'TIPO_OBRA', 'TOTAL_TECNICOS_ESTRANGEIROS', 'LOCAL_FILMAGEM']
df_film_estrang.columns = new_names
df_film_estrang['TOTAL_TECNICOS_ESTRANGEIROS'].fillna(3.0, inplace=True)
df_film_estrang['TOTAL_TECNICOS_ESTRANGEIROS'] = df_film_estrang['TOTAL_TECNICOS_ESTRANGEIROS'].astype(int)
df_film_estrang
# Out:
#                   TITULO_ORIGINAL
# 0                          MEUH !  \
# 1               VINCI CONCESSIONS
# 2               Girls meets world
# 3                 The Travel Show
# 4                 The Travel Show
# ..                            ...
# 96                         Animal
# 97   FOGO DE CHAO  Campaign 2021
# 98         Discover True Richness
# 99                Bitte Melde Dic
# 100                Unknown Amazon
#
#                                PRODUTORA_BRASILEIRA UF_PRODUTORA_BRASILEIRA
# 0                    IGOR DE MIRANDA OLSZOWSKI - ME                      RJ  \
# 1                    IGOR DE MIRANDA OLSZOWSKI - ME                      RJ
# 2                    Filmes to Go Produções Ltda ME                      RJ
# 3    Midia Fina producões cinematográficas - EIRELI                      SP
# 4    Midia Fina producões cinematográficas - EIRELI                      SP
# ..                                              ...                     ...
# ...

# %%
df_film_estrang.to_csv('film_estrang.csv')
