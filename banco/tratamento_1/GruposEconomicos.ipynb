# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %%
df_grupos_econ = pd.read_csv('GruposEconomicos.csv', encoding='latin1', sep=';')
df_grupos_econ
# Out:
#       REGISTRO_ANCINE        CNPJ_EMPRESA
# 0               20929  13.305.585/0001-08  \
# 1               18055  07.938.916/0001-36
# 2                3758  06.953.374/0001-08
# 3               28671  08.057.858/0001-02
# 4               34069  24.863.454/0001-54
# ...               ...                 ...
# 6136            52151  42.580.060/0001-70
# 6137            51651  46.833.682/0001-14
# 6138            52124  42.217.065/0001-33
# 6139            14105  08.304.465/0001-48
# 6140            50029  43.728.695/0001-35
#
#                                            RAZAO_SOCIAL
# 0            DE VILLE PRODUÇÕES AUDIOVISUAIS LTDA - EPP  \
# 1                                 CINEMA VILLAGGIO LTDA
# 2            ESPAÇO CULTURAL DE CINEMA DE SALVADOR LTDA
# 3     CINTIA E TIAGO ABRAVANEL PRODUÇÕES ARTISTICAS ...
# 4                          LA 9 PRODUTORA DE VÍDEO LTDA
# ...                                                 ...
# 6136      MAGNÍFICA EVENTOS CULTURAIS E ARTÍSTICOS LTDA
# 6137                                  LEMONADE LAB LTDA
# 6138                                   LUAH GARCIA LTDA
# 6139  GIOCONDA PRODUÇÕES ARTÍSTICAS E EDIÇÕES CULTUR...
# 6140       GENTE URBANA PRODUÇÕES CINEMATOGRÁFICAS LTDA
#
#                                       EMPRESA_ASSOCIADA CNPJ_EMPRESA_ASSOCIADA
# 0                                   FOCO PRODUÇÕES LTDA     02.803.873/0001-68
# 1                                 CINEARTE MORUMBI LTDA     05.774.116/0001-00
# 2                                 CINEARTE MORUMBI LTDA     05.774.116/0001-00
# 3                               TELEVISAO SOROCABA LTDA     53.653.945/0001-79
# 4                  OILHA AUDIOVISUAL STUDIO EIRELI - ME     95.134.573/0001-14
# ...                                                 ...                    ...
# 6136                    MAGNÍFICA PRODUÇÕES LTDA. - EPP     14.436.772/0001-85
# 6137                                    LEMONADE FILMES     21.674.572/0001-26
# 6138                                    CACTUS KID LTDA     46.773.343/0001-90
# 6139  MAFF DISTRIBUICAO E COMERCIALIZACAO DE FILMES ...     04.828.220/0001-69
# 6140                              PURE RED STUDIOS LTDA     31.935.854/0001-93
#
# [6141 rows x 5 columns]

# %%
df_grupos_econ.to_csv('to_replace.GruposEconomicos.csv')
