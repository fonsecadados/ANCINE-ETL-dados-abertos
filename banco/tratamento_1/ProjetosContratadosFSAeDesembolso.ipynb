# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# # Extração

# %%
df_proj_fsa_desemb = pd.read_csv('ProjetosContratadosFSAeDesembolso.csv', encoding='latin1', sep=';')
df_proj_fsa_desemb
# Out:
#      IDENTIFICACAO_CONTRATO                                    TITULO_PROJETO
# 0             02.09.0557.00                                  DE PERNAS PRO AR  \
# 1             02.09.0558.00                                         DESENROLA
# 2             02.09.0601.00         HISTÓRIAS DE AMOR DURAM APENAS 90 MINUTOS
# 3             02.09.0592.00                                         INSOLAÇÃO
# 4             02.09.0614.00                                  DO COMEÇO AO FIM
# ...                     ...                                               ...
# 3981              PR-03.882  LUPITA NO PLANETA DE GENTE GRANDE - 2ª TEMPORADA
# 3982              PR-03.948                             O SILÊNCIO DAS OSTRAS
# 3983              PR-03.916                      PANELA AMAZÔNIA 1ª TEMPORADA
# 3984              PR-03.874                                      DRAMATURGIAS
# 3985              PR-03.647                                               NaN
#
#                                         CHAMADA_PUBLICA ANO_CHAMADA_PUBLICA
# 0                                          PRODECINE 02                2008  \
# 1                                          PRODECINE 02                2008
# 2                                          PRODECINE 01                2008
# 3                                          PRODECINE 01                2008
# 4                                          PRODECINE 01                2008
# ...                                                 ...                 ...
# 3981                              PRODAV - TVS PÚBLICAS                2018
# 3982                                 ARRANJOS REGIONAIS                2017
# 3983                       PRODAV 02 - PROJETO DERIVADO                2016
# 3984                              PRODAV - TVS PÚBLICAS                2018
# 3985  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                2020
#
#          CNPJ_PROPONENTE                            RAZAO_SOCIAL_PROPONENTE
# 0     07.616.202/0001-01           FREESPIRIT DISTRIBUIDORA DE FILMES LTDA.  \
# 1     07.616.202/0001-01           FREESPIRIT DISTRIBUIDORA DE FILMES LTDA.
# 2     31.939.739/0001-97                      TIPOS E TEMPOS PRODUÇÕES LTDA
# 3     05.919.250/0001-43  CISMA PRODUÇÕES CINEMATOGRÁFICAS, EVENTOS E TE...
# 4     03.838.776/0001-73                    HARE FILMES PRODUCOES LTDA - ME
# ...                  ...                                                ...
# 3981  08.813.728/0001-44                         J O DE QUEIROGA NETO - EPP
# 3982  15.745.495/0001-55                                TEMPERO FILMES LTDA
# 3983  26.242.766/0001-76                                FONSECA & PAES LTDA
# 3984  29.555.333/0001-69                      R. SHIZUKO TAKAMATSU - FILMES
# 3985  02.812.929/0001-40                 CINE SÃO ROQUE DIVERSÕES LTDA - ME
#
#           CNPJ_PRODUTORA                             RAZAO_SOCIAL_PRODUTORA
# 0     42.473.256/0001-66                          MORENA FILMES EIRELI - ME  \
# 1     72.062.029/0001-09  RACCORD PRODUÇÕES ARTÍSTICAS E CINEMATOGRÁFICA...
# 2     31.939.739/0001-97                      TIPOS E TEMPOS PRODUÇÕES LTDA
# 3     05.919.250/0001-43  CISMA PRODUÇÕES CINEMATOGRÁFICAS, EVENTOS E TE...
# 4     03.838.776/0001-73                    HARE FILMES PRODUCOES LTDA - ME
# ...                  ...                                                ...
# 3981  08.813.728/0001-44                         J O DE QUEIROGA NETO - EPP
# 3982  15.745.495/0001-55                                TEMPERO FILMES LTDA
# 3983  26.242.766/0001-76                                FONSECA & PAES LTDA
# 3984  29.555.333/0001-69                      R. SHIZUKO TAKAMATSU - FILMES
# 3985                 NaN                                                NaN
#
#      CNPJ_DISTRIBUIDORA_PROGRAMADORA
# 0                 07.616.202/0001-01  \
# 1                 07.616.202/0001-01
# 2                 07.616.202/0001-01
# 3                 72.672.017/0001-04
# 4                 07.616.202/0001-01
# ...                              ...
# 3981                             NaN
# 3982              28.083.221/0001-90
# 3983              07.254.174/0001-20
# 3984                             NaN
# 3985                             NaN
#
#                 RAZAO_SOCIAL_DISTRIBUIDORA_PROGRAMADORA
# 0              FREESPIRIT DISTRIBUIDORA DE FILMES LTDA.  \
# 1              FREESPIRIT DISTRIBUIDORA DE FILMES LTDA.
# 2              FREESPIRIT DISTRIBUIDORA DE FILMES LTDA.
# 3                                  CANNES PRODUÇÕES S/A
# 4              FREESPIRIT DISTRIBUIDORA DE FILMES LTDA.
# ...                                                 ...
# 3981                                                NaN
# 3982  OLHAR DE CINEMA DISTRIBUIDORA DE FILMES LTDA - ME
# 3983     PBI - PROGRAMADORA BRASILEIRA INDEPENDENTE S.A
# 3984                                                NaN
# 3985                                                NaN
#
#      DT_PUBLICACAO_CONTRATO_DOU VL_CONTRATO_DOU DT_PRIMEIRO_DESEMBOLSO
# 0                    08/12/2009      3000000,00             21/12/2009  \
# 1                    08/12/2009      2000000,00             21/12/2009
# 2                    24/12/2009       300000,00             13/01/2010
# 3                    24/12/2009       500000,00             15/01/2010
# 4                    29/12/2009       461740,00             13/01/2010
# ...                         ...             ...                    ...
# 3981                 18/02/2021      2000000,00                    NaN
# 3982                 18/02/2021      1650000,00                    NaN
# 3983                 18/02/2021       435143,47                    NaN
# 3984                 22/02/2021      1000000,00                    NaN
# 3985                 22/02/2021        34153,69                    NaN
#
#      VL_TOTAL_LIBERADO
# 0           3000000,00
# 1           2000000,00
# 2            300000,00
# 3            500000,00
# 4            461740,00
# ...                ...
# 3981               NaN
# 3982               NaN
# 3983               NaN
# 3984               NaN
# 3985               NaN
#
# [3986 rows x 14 columns]

# %%
# Tratando valores nulos
def fill_null(df, coluna, fill):
    df[coluna].fillna(fill, inplace=True)

fill_null(df_proj_fsa_desemb, 'TITULO_PROJETO', 'NÃO FILME')
fill_null(df_proj_fsa_desemb, 'CNPJ_PRODUTORA', 'SEM PRODUTORA')
fill_null(df_proj_fsa_desemb, 'RAZAO_SOCIAL_PRODUTORA', 'SEM PRODUTORA')
fill_null(df_proj_fsa_desemb, 'CNPJ_DISTRIBUIDORA_PROGRAMADORA', 'SEM DISTRIBUIDORA/PROGRAMADORA')
fill_null(df_proj_fsa_desemb, 'RAZAO_SOCIAL_DISTRIBUIDORA_PROGRAMADORA', 'SEM DISTRIBUIDORA/PROGRAMADORA')
fill_null(df_proj_fsa_desemb, 'DT_PRIMEIRO_DESEMBOLSO', 'SEM DESEMBOLSO')

# to_datetime
def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')

to_datetime(df_proj_fsa_desemb, 'DT_PUBLICACAO_CONTRATO_DOU')
#to_datetime(df_proj_fsa_desemb, 'DT_PRIMEIRO_DESEMBOLSO')

# Float
def convert_to_float(df, coluna):
    df[coluna] = df[coluna].apply(lambda x: float(str(x).replace(',', '.')) if isinstance(x, (str, float)) else x)

convert_to_float(df_proj_fsa_desemb, 'VL_CONTRATO_DOU')
convert_to_float(df_proj_fsa_desemb, 'VL_TOTAL_LIBERADO')

# to replace
def replace(df, coluna, old_value, new_value):
    df[coluna].replace(old_value, new_value, inplace=True)

replace(df_proj_fsa_desemb, 'ANO_CHAMADA_PUBLICA', '2017/2018', 2017)
replace(df_proj_fsa_desemb, 'ANO_CHAMADA_PUBLICA', '2017/2018/2018', 2017)

df_proj_fsa_desemb['ANO_CHAMADA_PUBLICA'] = pd.to_datetime(df_proj_fsa_desemb['ANO_CHAMADA_PUBLICA'], format='%Y').dt.year
fill_null(df_proj_fsa_desemb, 'VL_TOTAL_LIBERADO', 0)

# %%
df_proj_fsa_desemb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3986 entries, 0 to 3985
# Data columns (total 14 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   IDENTIFICACAO_CONTRATO                   3986 non-null   object
#  1   TITULO_PROJETO                           3986 non-null   object
#  2   CHAMADA_PUBLICA                          3986 non-null   object
#  3   ANO_CHAMADA_PUBLICA                      3986 non-null   int32
#  4   CNPJ_PROPONENTE                          3986 non-null   object
#  5   RAZAO_SOCIAL_PROPONENTE                  3986 non-null   object
#  6   CNPJ_PRODUTORA                           3986 non-null   object
#  7   RAZAO_SOCIAL_PRODUTORA                   3986 non-null   object
#  8   CNPJ_DISTRIBUIDORA_PROGRAMADORA          3986 non-null   object
#  9   RAZAO_SOCIAL_DISTRIBUIDORA_PROGRAMADORA  3986 non-null   object
#  10  DT_PUBLICACAO_CONTRATO_DOU               3986 non-null   datetime64[ns]
#  11  VL_CONTRATO_DOU                          3986 non-null   float64
#  12  DT_PRIMEIRO_DESEMBOLSO                   3986 non-null   object
#  13  VL_TOTAL_LIBERADO                        3986 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int32(1), object(10)
# memory usage: 420.5+ KB

# %% [markdown]
# ---

# %%
df_proj_fsa_desemb.to_csv('to_replace.ProjetosContratadosFSAeDesembolso.csv')
