# %%
import pandas as pd
import numpy as np

# %%
df_prg_apoio_mercado = pd.read_csv('ProgramaApoioAMercados.csv', encoding='latin1', sep=';')
df_prg_apoio_mercado
# Out:
#      NOME_EVENTO DT_INICIO_EVENTO DT_TERMINO_EVENTO
# 0       EFM 2019       07/02/2019        15/02/2019  \
# 1       EFM 2019       07/02/2019        15/02/2019
# 2       EFM 2019       07/02/2019        15/02/2019
# 3       EFM 2019       07/02/2019        15/02/2019
# 4       EFM 2019       07/02/2019        15/02/2019
# ..           ...              ...               ...
# 98   MIPCOM 2019       14/10/2019        17/10/2019
# 99   MIPCOM 2019       14/10/2019        17/10/2019
# 100  MIPCOM 2019       14/10/2019        17/10/2019
# 101  MIPCOM 2019       14/10/2019        17/10/2019
# 102     MIA 2019       16/10/2019        20/10/2019
#
#                            RAZAO_SOCIAL_PRODUTORA      CNPJ_PRODUTORA
# 0                       Gullane Entretenimento SA  01.378.559/0001-12  \
# 1                   OCEAN PRODUCAO DE FILMES LTDA  04.069.379/0001-47
# 2    Eder San Júnior Cinematográfica e Arte Ltda.  09.207.344/0001-40
# 3           Dezenove Som e Imagens Produções Ltda  66.876.707/0001-74
# 4                       Anavilhana Filmes Ltda-ME  07.525.577/0001-66
# ..                                            ...                 ...
# 98           Hype Studio Computação Gráfica Ltda.  10.730.207/0001-75
# 99          Flux Game Studio Jogos Digitais Ltda.  17.212.680/0001-00
# 100                   Leonardo Garcia e Cia Ltda.  11.384.969/0001-20
# 101                       Sentimental Filme Ltda.  05.326.727/0001-87
# 102                    Elka Filmes e Comunicações  13.014.874/0001-40
#
#                                          REPRESENTANTE VALOR_APOIO_FINANCEIRO
# 0                                      Fabiano Gullane                 4600,0
# 1                              JOAO RONI JARDIM GARCIA                 4600,0
# 2    André Hallak Martins da Costa Camilo Guimarães...                 4600,0
# 3                            Jussara Nunes da Silveira                 4600,0
# 4                          Luana Melgaço Silva Marques                 4600,0
# ..                                                 ...                    ...
# 98                                      Gabriel Garcia                 4600,0
# 99                       Paulo Luis Barbosa dos Santos                 4600,0
# 100                                    Leonardo Garcia                 4600,0
# 101                            Juliana Fernandes Bauer                 4600,0
# 102                           Daniel Gonçalves Camargo                 4600,0
#
# [103 rows x 7 columns]

# %%
#to_datetime
def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')

#to float
def convert_to_float(df, coluna):
    df[coluna] = df[coluna].apply(lambda x: float(x.replace(',','.')))

convert_to_float(df_prg_apoio_mercado, 'VALOR_APOIO_FINANCEIRO')
to_datetime(df_prg_apoio_mercado, 'DT_INICIO_EVENTO')
to_datetime(df_prg_apoio_mercado, 'DT_TERMINO_EVENTO')

# %%
df_prg_apoio_mercado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NOME_EVENTO             103 non-null    object
#  1   DT_INICIO_EVENTO        103 non-null    datetime64[ns]
#  2   DT_TERMINO_EVENTO       103 non-null    datetime64[ns]
#  3   RAZAO_SOCIAL_PRODUTORA  103 non-null    object
#  4   CNPJ_PRODUTORA          103 non-null    object
#  5   REPRESENTANTE           103 non-null    object
#  6   VALOR_APOIO_FINANCEIRO  103 non-null    float64
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 5.8+ KB

# %%
df_prg_apoio_mercado.to_csv('to_replace.ProgramaApoioAMercados.csv', encoding='utf-8', index=False)
