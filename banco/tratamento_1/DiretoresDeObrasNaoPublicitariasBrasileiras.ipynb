# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# # Extração

# %%
df_dir_publi_br = pd.read_csv('DiretoresDeObrasNaoPublicitariasBrasileiras.csv', encoding='latin1', sep=';')
df_dir_publi_br
# Out:
#                     CPB                                    TITULO_ORIGINAL
# 0      B0200000400000    SEJA O QUE DEUS QUISER                        ...  \
# 1      B0200000600000    ROCINHA BRASIL77                              ...
# 2      B0200000700000    ROCINHA 76/96                                 ...
# 3      B0200000800000    NANDERU - PANORÂMICA TUPINAMBÁ                ...
# 4      B0200000900000    ABC BRASIL                                    ...
# ...                 ...                                                ...
# 57391  B2300170600000    FAMÍLIA PARAÍSO - 2ª TEMPORADA                ...
# 57392  B2300170700000    BARRO SANTO: MÃO E FÉ                         ...
# 57393  B2300170800000    UM POETA NO MEIO DOS POETAS                   ...
# 57394  B2300170800000    UM POETA NO MEIO DOS POETAS                   ...
# 57395  B600566000000     CONVERSA FIADA                                ...
#
#                                                  DIRETOR
# ...

# %%
df_dir_publi_br.to_csv('to_replace.DiretoresDeObrasNaoPublicitariasBrasileiras.csv', encoding='utf-8', index=False)
