# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# # Extração

# %%
df_canal_distrib_obrig = pd.read_csv('CanaisDeDistribuicaoObrigatoria.csv', encoding='latin1', sep=';')
df_canal_distrib_obrig.head(10)
# Out:
#                                           CANAL NR_IDENTIFICACAO
# 0                              CANAL AMAZON SAT     16959.30001   \
# 1                              CANAL CAPIBARIBE     41339.30001
# 2  CANAL COMUNITÁRIO - TV SETE LAGOAS - CANAL 9     32247.30001
# 3              CANAL COMUNITÁRIO DE NOVA ODESSA     52079.30001
# 4                   CANAL COMUNITÁRIO DE SUZANO     41631.30001
# 5                     CANAL COMUNITÁRIO TAUBATÉ     37948.30001
# 6                                  CANAL PLURAL     29164.30001
# 7   CANAL UNIVERSITÁRIO DO RIO DE JANEIRO - UTV     28617.30001
# 8                     EA - EMISSORAS ASSOCIADAS     36079.30001
# 9                                  FTVE JUNDIAÍ     36005.30001
#
#   CLASSIFICACAO_CANAL TIPO_CONTEUDO_CANAL                     OFERTA_CLIENTE
# 0                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA  \
# 1                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 2                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 3                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 4                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 5                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 6                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 7                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 8                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
# 9                 NaN                 NaN  CANAL DE DISTRIBUIÇÃO OBRIGATÓRIA
#
#   DATA_INICIO_OFERTA DENSIDADE_CANAL
# 0         03/05/2004          PADRÃO  \
# 1         21/11/2001          PADRÃO
# 2         23/05/2007          PADRÃO
# 3         01/10/2022          PADRÃO
# 4         20/03/2018          PADRÃO
# 5         21/10/2002          PADRÃO
# 6         01/02/2017          PADRÃO
# 7         31/08/1999          PADRÃO
# 8         17/05/2014          PADRÃO
# 9         01/04/2017          PADRÃO
#
#                                    NOME_PROGRAMADORA   CNPJ_PROGRAMADORA
# 0                                 AMAZONIA CABO LTDA  02.311.604/0001-84  \
# 1  ASSOCIAÇÃO DOS CONSTITUINTES E USUÁRIOS DO CAN...  05.204.826/0001-96
# 2  ASSOCIAÇÃO ENTIDADES CANAL COMUNITÁRIO DE TVS ...  09.022.292/0001-38
# 3  INSTITUTO DE COMUNICAÇÃO INTEGRADO DE NOVA ODE...  46.264.074/0001-36
# 4  INSTITUTO DE MEMÓRIA AUDIOVISUAL DE MOGI DAS C...  27.438.143/0001-36
# 5             REDE CIDADE DE COMUNICACAO E CIDADANIA  05.356.414/0001-71
# 6                             ASSOCIAÇÃO CELEBREIROS  03.159.024/0001-86
# 7  ASSOCIAÇÃO DE TELEVISÃO DAS UNIVERSIDADES DO R...  02.833.278/0001-75
# 8                                   INSTITUTO ABCCOM  20.800.979/0001-90
# 9            FUNDAÇÃO TELEVISÃO EDUCATIVA DE JUNDIAÍ  02.150.976/0001-76
#
#   CLASSIFICAO_PROGRAMADORA PAIS_PROGRAMADORA
# 0                      NaN            BRASIL
# 1                      NaN            BRASIL
# 2                      NaN            BRASIL
# 3                      NaN            BRASIL
# 4                      NaN            BRASIL
# 5                      NaN            BRASIL
# 6                      NaN            BRASIL
# 7                      NaN            BRASIL
# 8                      NaN            BRASIL
# 9                      NaN            BRASIL

# %%
df_canal_distrib_obrig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CANAL                     60 non-null     object
#  1   NR_IDENTIFICACAO          60 non-null     object
#  2   CLASSIFICACAO_CANAL       5 non-null      object
#  3   TIPO_CONTEUDO_CANAL       5 non-null      object
#  4   OFERTA_CLIENTE            60 non-null     object
#  5   DATA_INICIO_OFERTA        60 non-null     object
#  6   DENSIDADE_CANAL           60 non-null     object
#  7   NOME_PROGRAMADORA         60 non-null     object
#  8   CNPJ_PROGRAMADORA         60 non-null     object
#  9   CLASSIFICAO_PROGRAMADORA  2 non-null      object
#  10  PAIS_PROGRAMADORA         60 non-null     object
# dtypes: object(11)
# memory usage: 5.3+ KB

# %%
#Fill Null
def fill_null(df, coluna, fill):
    df[coluna].fillna(fill, inplace=True)

fill_null(df_canal_distrib_obrig, 'CLASSIFICACAO_CANAL', 'SEM INFORMAÇÃO')
fill_null(df_canal_distrib_obrig, 'TIPO_CONTEUDO_CANAL', 'SEM INFORMAÇÃO')
fill_null(df_canal_distrib_obrig, 'CLASSIFICAO_PROGRAMADORA', 'SEM INFORMAÇÃO')

#convert values
def convert_to(df, coluna):
    df[coluna] = df[coluna].astype(float)

convert_to(df_canal_distrib_obrig, 'NR_IDENTIFICACAO')

#to_datetime
def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)

to_datetime(df_canal_distrib_obrig, 'DATA_INICIO_OFERTA')

# %% [markdown]
# ---

# %%
df_canal_distrib_obrig.to_csv('to_replace.CanaisDeDistribuicaoObrigatoria.csv', encoding='utf-8', index=False)
