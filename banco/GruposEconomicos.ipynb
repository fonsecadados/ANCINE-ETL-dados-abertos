# %%
import pandas as pd
import numpy as np

# %%
df_grup_econ = pd.read_csv('GruposEconomicos.csv', encoding='latin1', sep=';')
df_grup_econ = df_grup_econ[['REGISTRO_ANCINE', 'RAZAO_SOCIAL', 'EMPRESA_ASSOCIADA']]
df_grup_econ
# Out:
#       REGISTRO_ANCINE                                       RAZAO_SOCIAL
# 0               20929         DE VILLE PRODUÇÕES AUDIOVISUAIS LTDA - EPP  \
# 1               18055                              CINEMA VILLAGGIO LTDA
# 2                3758         ESPAÇO CULTURAL DE CINEMA DE SALVADOR LTDA
# 3               28671  CINTIA E TIAGO ABRAVANEL PRODUÇÕES ARTISTICAS ...
# 4               34069                       LA 9 PRODUTORA DE VÍDEO LTDA
# ...               ...                                                ...
# 6136            52151      MAGNÍFICA EVENTOS CULTURAIS E ARTÍSTICOS LTDA
# 6137            51651                                  LEMONADE LAB LTDA
# 6138            52124                                   LUAH GARCIA LTDA
# 6139            14105  GIOCONDA PRODUÇÕES ARTÍSTICAS E EDIÇÕES CULTUR...
# 6140            50029       GENTE URBANA PRODUÇÕES CINEMATOGRÁFICAS LTDA
#
#                                       EMPRESA_ASSOCIADA
# ...

# %%
df_grup_econ.to_csv('grupo_econ.csv')
