# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %%
df_salas_exib = pd.read_csv('SalasDeExibicaoEComplexos.csv', encoding='latin1', sep=';')
df_salas_exib
# Out:
#                                 NOME_SALA  REGISTRO_SALA           CNPJ_SALA
# 0                             CINE SEGALL      5004892.0  60.262.086/0001-52  \
# 1     CINESERCLA NILÓPOLIS SQUARE SALA 01      5002318.0  03.879.383/0004-50
# 2     CINESERCLA NILÓPOLIS SQUARE SALA 02      5002319.0  03.879.383/0004-50
# 3     CINESERCLA NILÓPOLIS SQUARE SALA 03      5002317.0  03.879.383/0004-50
# 4        CINESERCLA PÁTIO ITAGUAÍ SALA 01      5003016.0  03.879.383/0003-70
# ...                                   ...            ...                 ...
# 3691           CINE CARIOCA NOVA BRASÍLIA      5006698.0  36.563.373/0001-18
# 3692                    WEST CINE SALA 01      5006809.0  44.246.458/0001-09
# 3693                    WEST CINE SALA 02      5006810.0  44.246.458/0001-09
# 3694                    WEST CINE SALA 03      5006811.0  44.246.458/0001-09
# 3695  CINEMEC TAQUARITINGA - CINE MIZIARA      5005891.0  26.102.065/0001-31
#
# ...

# %%
df_salas_exib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NOME_SALA                   3675 non-null   object
#  1   REGISTRO_SALA               3675 non-null   float64
#  2   CNPJ_SALA                   3696 non-null   object
#  3   SITUACAO_SALA               3675 non-null   object
#  4   ASSENTOS_SALA               3675 non-null   float64
#  5   NOME_COMPLEXO               3696 non-null   object
#  6   REGISTRO_COMPLEXO           3696 non-null   int64
#  7   PAGINA_ELETRONICA_COMPLEXO  2496 non-null   object
#  8   ENDERECO_COMPLEXO           3675 non-null   object
#  9   NUMERO_ENDERECO_COMPLEXO    3605 non-null   float64
#  10  COMPLEMENTO_COMPLEXO        2946 non-null   object
#  11  BAIRRO_COMPLEXO             3675 non-null   object
#  12  MUNICIPIO_COMPLEXO          3675 non-null   object
# ...
