# %%
import pandas as pd
import numpy as np

# %%
#início e fim do data set
.head()
.tail()

#sumário do dataset(cabeçalho)
.info()

#datatype de cada coluna
.dtypes()

#numero de linhas e colunas
.shape()

#multiplica linha x coluna
.size()

#sumário estatístico do dataset
.describe()
.describe(include=all)

#seleciona amostra randômica no dataset
.sample(n=x)

#identifica valores nulos
.isnull()
.isna()

#calcula valores
.sum()
ex: .isnull().sum()

#exibe valores únicos de uma coluna na tabela
.unique()

#exibe o numero de valores
.nunique()

#conta os valores
.value_counts()

#buscar um elemento nop índice
.index()
ex: .index(start=0, stop=120, step=2) #ler do primeiro ao indíce numero 120, pulando de 2 em 2

#mostra os títulos das colunas
.columns()

#mostra gastos de memória
.memory_usage()

#os maiores e os menores de um índice
.nsmallest()
.nlargest()

#localiza e seleciona linhas ou colunas
.loc[0:0,['data1', 'data2', 'data_n']] #busca por label (strings)
.iloc[0:0,0:0] #busca por position (numero)

#slice - selecionar um frame do dataset
ex: df_set[0:4]

#agrupar 
df_set[['df1', 'df2', 'dfn']].groupby(['df1', 'df2', 'dfn'])

#ordenar índice
.sort_index(axis=1, ascending=True)

#ordenar por valor de coluna
.sort_values(by='df_set')

#remove a row or a column from a dataframe which has a NaN or no values in it
.dropna()

# filter a dataframe based on a condition or apply a mask to get certain values.
.query()

#insert 
.insert('')

#ADD NOVA COLUNA
#metodo 1
df.assign(coluna='valor')

#metodo 2
df['criar nome pra coluna'] = 'valor'

#metodo 3 - operação
df['criar coluna'] = df['coluna1']/df['coluna2']

#metodo 4 loc
df.loc[df['coluna existente'] > valor, 'nome da nova coluna'] = True

#RESETAR INDICE
.reset_index()
.set_index()

#preencher valores nulos
.fillna()
.fillna(method='ffill')
.fillna(method='bfill')

#PROCESSO TRATAR NULOS
.isna() | .dropna() | .fillna()

#replace
df['df'].replace({'A':'a', 'B':'b'})
# Out:
#   Cell In[2], line 2
#     .head()
#     ^
# SyntaxError: invalid syntax
