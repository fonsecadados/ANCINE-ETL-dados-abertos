# %%
import pandas as pd
import numpy as np

# %%
cnpjs_to_check = [
 '40.222.072/0001-06',
 '49.405.221/0001-39',
 '15.131.165/0001-70',
 '12.301.061/0001-78',
 '10.763.360/0001-07',
 '25.990.290/0001-99',
 '03.425.449/0001-90',
 '15.651.792/0001-31',
 '46.343.097/0001-36',
 '32.177.367/0001-71',
 '35.751.309/0001-06',
 '45.589.940/0001-04',
 '26.421.082/0001-31',
 '32.337.237/0001-59',
 '21.916.610/0001-00',
 '33.753.853/0001-53',
 '32.605.071/0001-04',
 '42.119.387/0001-40',
 '30.013.364/0001-77',
 '03.172.036/0001-40',
 '40.923.297/0001-81',
 '42.701.098/0001-54',
 '43.206.211/0001-98',
 '12.530.623/0001-55',
 '24.575.039/0001-03',
 '05.804.377/0001-17',
 '30.350.510/0001-50',
 '32.558.054/0001-63',
 '03.861.448/0001-98',
 '29.708.938/0001-42',
 '21.351.722/0001-60',
 '34.211.341/0001-28',
 '14.992.876/0001-76',
 '34.107.095/0001-69',
 '24.241.892/0001-80',
 '36.219.247/0001-40',
 '40.226.313/0001-87',
 '42.999.841/0001-02',
 '24.147.907/0001-46',
 '14.210.788/0001-75',
 '16.806.723/0001-12',
 '42.220.837/0001-96',
 '13.546.570/0001-23',
 '49.371.962/0001-46',
 '29.995.994/0001-05',
 '19.962.586/0001-01',
 '19.974.069/0001-44',
 '16.877.661/0001-30',
 '44.537.226/0001-00',
 '33.625.380/0001-09',
 '31.330.222/0001-04',
 '02.616.581/0001-16',
 '32.243.334/0001-82',
 '13.373.053/0001-08',
 '09.385.630/0001-04',
 '42.152.957/0001-01',
 '14.651.453/0001-92',
 '35.862.793/0001-32',
 '04.585.783/0001-73',
 '28.999.862/0001-99',
 '31.478.621/0001-09',
 '10.634.153/0001-44',
 '00.589.339/0001-75',
 '28.298.402/0001-33',
 '37.064.188/0001-41',
 '37.184.804/0001-06',
 '12.476.637/0001-38',
 '30.967.902/0001-62',
 '33.561.124/0001-03',
 '14.985.732/0001-92',
 '00.414.568/0001-59',
 '25.103.064/0001-49',
 '31.529.645/0001-40',
 '35.684.520/0001-45',
 '20.811.009/0001-90',
 '13.380.867/0001-61',
 '44.471.132/0001-77',
 '04.201.181/0001-75',
 '42.856.251/0001-12',
 '03.692.683/0001-83',
 '24.734.932/0001-26',
 '15.693.797/0001-27',
 '08.103.899/0001-80',
 '43.032.269/0001-62',
 '18.589.962/0001-93',
 '09.134.587/0001-04',
 '17.140.796/0001-80',
 '25.912.530/0001-37',
 '11.982.842/0001-02',
 '13.088.643/0001-80',
 '21.710.727/0001-32',
 '32.261.592/0001-91',
 '46.641.605/0001-62',
 '29.116.285/0001-02',
 '29.621.500/0001-22',
 '44.681.987/0001-22',
 '27.065.150/0001-30',
 '34.430.442/0001-90',
 '02.737.078/0001-19',
 '20.533.821/0001-09',
 '39.341.953/0001-59',
 '10.613.523/0001-67',
 '30.553.792/0001-92',
 '26.682.199/0001-79',
 '14.410.301/0001-06',
 '11.136.684/0001-70',
 '34.532.932/0001-05',
 '31.876.653/0001-62',
 '49.039.943/0001-17',
 '17.151.166/0001-01',
 '15.757.699/0001-06',
 '28.921.806/0001-31',
 '09.208.990/0001-22',
 '11.609.242/0001-01',
 '32.290.770/0001-02',
 '27.329.556/0001-82',
 '21.065.201/0001-47',
 '20.518.008/0001-51',
 '12.379.149/0001-02',
 '37.114.074/0001-69',
 '21.443.150/0001-40',
 '49.564.368/0001-71',
 '04.676.620/0001-04',
 '14.165.196/0001-89',
 '16.595.181/0001-86',
 '13.981.640/0001-71',
 '34.941.850/0001-06',
 '08.434.432/0001-12',
 '13.958.660/0001-21',
 '39.794.680/0001-06',
 '44.135.340/0001-03',
 '04.920.643/0001-04',
 '17.195.358/0001-10',
 '18.670.862/0001-97',
 '21.141.011/0001-61',
 '18.580.137/0001-28',
 '31.451.298/0001-80',
 '43.380.531/0001-60',
 '29.611.853/0001-41',
 '29.031.260/0001-06',
 '31.116.435/0001-20',
 '17.727.654/0001-14',
 '14.876.344/0001-73',
 '29.971.842/0001-72',
 '44.447.754/0001-60',
 '24.879.526/0001-51',
 '01.915.175/0001-91',
 '32.992.475/0001-06',
 '17.714.670/0001-72',
 '07.162.196/0001-60',
 '39.741.470/0001-41',
 '14.240.951/0001-42',
 '35.587.888/0001-95',
 '18.162.501/0001-30',
 '26.033.493/0001-50',
 '16.370.907/0001-82',
 '04.769.554/0001-09',
 '20.801.818/0001-10',
 '30.227.228/0001-80',
 '32.719.785/0001-43',
 '09.445.277/0001-00',
 '22.810.678/0001-72',
 '14.635.446/0001-05',
 '42.128.343/0001-86',
 '10.852.692/0001-50',
 '26.671.292/0001-88',
 '31.750.022/0001-00',
 '19.628.647/0001-90',
 '21.033.878/0001-01',
 '32.479.123/0001-43',
 '23.572.489/0001-71',
 '24.381.120/0001-44',
 '31.689.843/0001-70',
 '10.960.415/0001-60',
 '26.089.873/0001-06',
 '00.373.973/0001-76',
 '18.202.976/0001-02',
 '30.428.516/0001-00',
 '21.797.177/0001-30',
 '09.369.796/0001-29',
 '13.318.058/0001-20',
 '27.478.257/0001-00',
 '23.717.729/0001-89',
 '23.923.441/0001-60',
 '27.419.100/0001-03',
 '19.387.261/0001-34',
 '36.565.202/0001-28',
 '13.991.594/0001-91',
 '17.119.823/0001-33',
 '33.378.866/0001-90',
 '08.030.429/0001-33',
 '16.994.240/0001-99',
 '36.049.641/0001-88',
 '06.914.274/0001-72',
 '33.998.771/0001-79',
 '12.354.771/0001-66',
 '26.349.364/0001-75',
 '17.591.225/0001-62',
 '31.458.492/0001-97',
 '31.859.201/0001-72',
 '37.281.569/0001-82',
 '31.449.125/0001-27',
 '34.853.340/0001-87',
 '40.203.694/0001-89',
 '49.129.924/0001-81',
 '39.246.925/0001-52',
 '15.121.862/0001-40',
 '27.585.858/0001-11',
 '14.128.876/0001-22',
 '26.203.415/0001-56',
 '12.663.752/0001-11',
 '03.132.906/0001-58',
 '21.681.140/0001-42',
 '29.821.631/0001-53',
 '18.012.019/0001-13',
 '31.703.432/0001-92',
 '35.220.801/0001-47',
 '28.548.077/0001-10',
 '05.878.063/0001-69',
 '08.427.216/0001-40',
 '22.869.009/0001-76',
 '32.577.562/0001-99',
 '31.639.889/0001-85',
 '43.261.669/0001-40',
 '03.694.276/0001-05',
 '24.890.666/0001-20',
 '20.964.886/0001-09',
 '29.086.297/0001-31',
 '08.101.204/0001-20',
 '18.008.314/0001-04',
 '13.967.089/0001-01',
 '17.652.148/0001-03',
 '11.767.820/0001-20',
 '31.964.490/0001-70',
 '18.391.109/0001-62',
 '46.850.630/0001-56',
 '31.621.283/0001-12',
 '05.077.549/0001-06',
 '28.754.676/0001-90',
 '45.795.915/0001-79',
 '41.303.412/0001-88',
 '33.113.878/0001-92',
 '11.365.117/0001-95',
 '16.649.153/0001-02',
 '10.434.099/0001-93',
 '33.880.406/0001-65',
 '11.144.385/0001-87',
 '39.306.027/0001-42',
 '41.243.402/0001-02',
 '37.893.600/0001-36',
 '04.018.247/0001-96',
 '29.779.707/0001-20',
 '18.086.583/0001-80',
 '42.351.422/0001-51'
]

# %% [markdown]
# ### Agentes Econômicos Regulares

# %%
df_ag_econ_reg = pd.read_csv('AgentesEconomicosRegulares.csv')

def to_datetime(df, coluna, date_format):
    df[coluna] = pd.to_datetime(df[coluna], format=date_format)

to_datetime(df_ag_econ_reg, 'DATA_REGISTRO', '%Y-%m-%d')

#Filtrando para UF = ES
df_ag_econ_reg

df_ag_econ_reg_es = df_ag_econ_reg[df_ag_econ_reg['UF'] == 'ES']

#Removendo CPF

def remove_numbers(razao_social):
    return razao_social[:-11] if razao_social and razao_social[-11:].isdigit() else razao_social

df_ag_econ_reg_es['RAZAO_SOCIAL'] = df_ag_econ_reg_es['RAZAO_SOCIAL'].apply(remove_numbers)

def replace(df, column, old_value, new_value):
    df[column].replace(old_value, new_value, inplace=True)

replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.405.221 FREDERICO DO SACRAMENTO JANUARIO', 'FREDERICO DO SACRAMENTO JANUARIO')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.371.962 TIAGO DOS SANTOS MATHEUS', 'TIAGO DOS SANTOS MATHEUS')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '33.561.124 WILLIAM LEGORA SILVESTRE', 'WILLIAM LEGORA SILVESTRE')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '44.471.132 HERICA SANTOS DUARTE GODOY', 'HERICA SANTOS DUARTE GODOY')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.039.943 SARA DOS SANTOS SILVA ENGELHARDT', 'SARA DOS SANTOS SILVA ENGELHARDT')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.564.368 LARISSA MUNIZ MARANHÃO GUSMÃO', 'LARISSA MUNIZ MARANHÃO GUSMÃO')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '29.971.842 GRASIELLE FINK DA SILVA', 'GRASIELLE FINK DA SILVA')
replace(df_ag_econ_reg_es, 'RAZAO_SOCIAL', '49.129.924 IRINEU CRUZEIRO NETO', 'IRINEU CRUZEIRO NETO')

df_ag_econ_reg_es
# Out:
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3645913882.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ag_econ_reg_es['RAZAO_SOCIAL'] = df_ag_econ_reg_es['RAZAO_SOCIAL'].apply(remove_numbers)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3645913882.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column].replace(old_value, new_value, inplace=True)
#        REGISTRO_ANCINE DATA_REGISTRO
# 16               47652    2021-02-01  \
# 28               52739    2023-02-01
# 161              24509    2013-07-01
# 231              17645    2010-09-01
# 233              19578    2011-09-01
# ...                ...           ...
# 14549            52449    2022-11-30
# 14568            52547    2022-12-30
# 14610            52733    2023-01-31
# 14691            48520    2021-05-31
# 14758            49402    2021-08-31
#
#                                             RAZAO_SOCIAL                CNPJ
# 16                    ATROM PRODUCOES E CONSULTORIA LTDA  40.222.072/0001-06  \
# 28                      FREDERICO DO SACRAMENTO JANUARIO  49.405.221/0001-39
# 161                                 MIRARTES FILMES LTDA  15.131.165/0001-70
# 231                         TK 1 VIDEO PRODUÇÕES LTDA ME  12.301.061/0001-78
# 233        CEC - CENTRO DE ENTRETENIMENTO CONCEIÇÃO LTDA  10.763.360/0001-07
# ...                                                  ...                 ...
# 14549                                   JOSE L N PEIXOTO  37.893.600/0001-36
# 14568  ASSOCIAÇÃO ARTISTICA E FOLCLORICA AFRO BRASILE...  04.018.247/0001-96
# 14610                        JOÃO OLIVEIRA DE PAIVA NETO  29.779.707/0001-20
# 14691         FILMES DA ILHA PRODUÇÕES AUDIOVISUAIS LTDA  18.086.583/0001-80
# 14758                          LEONARDO BARBOSA ROSINDO   42.351.422/0001-51
#
#         MUNICIPIO  CD_MUNICIPIO_IBGE  UF
# 16        VITÓRIA          3205309.0  ES  \
# 28        VITÓRIA          3205309.0  ES
# 161       VITÓRIA          3205309.0  ES
# 231       ARACRUZ          3200607.0  ES
# 233      LINHARES          3203205.0  ES
# ...           ...                ...  ..
# 14549  MARATAÍZES          3203320.0  ES
# 14568   CARIACICA          3201308.0  ES
# 14610     VITÓRIA          3205309.0  ES
# 14691     VITÓRIA          3205309.0  ES
# 14758     VITÓRIA          3205309.0  ES
#
#                           CLASSIFICACAO_AGENTE_ECONOMICO
# 16                              Brasileiro independente
# 28     Brasileiro de capital nacional nos termos do a...
# 161                             Brasileiro independente
# 231                             Brasileiro independente
# 233    Brasileiro de capital nacional nos termos do a...
# ...                                                  ...
# 14549                           Brasileiro independente
# 14568  Brasileiro de capital nacional nos termos do a...
# 14610                           Brasileiro independente
# 14691                           Brasileiro independente
# 14758  Brasileiro de capital nacional nos termos do a...
#
# [254 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# ###  Projetos FSA e Desembolso

# %%
df_proj_fsa_desemb = pd.read_csv('ProjetosContratadosFSAeDesembolso.csv')
df_proj_fsa_desemb

df_proj_fsa_desemb_clean = df_proj_fsa_desemb[['IDENTIFICACAO_CONTRATO', 'TITULO_PROJETO', 'CHAMADA_PUBLICA',
       'ANO_CHAMADA_PUBLICA', 'CNPJ_PROPONENTE', 'RAZAO_SOCIAL_PROPONENTE',
       'RAZAO_SOCIAL_PRODUTORA',
       'RAZAO_SOCIAL_DISTRIBUIDORA_PROGRAMADORA', 'DT_PUBLICACAO_CONTRATO_DOU',
       'VL_CONTRATO_DOU', 'DT_PRIMEIRO_DESEMBOLSO', 'VL_TOTAL_LIBERADO']]



def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')

to_datetime(df_proj_fsa_desemb_clean, 'DT_PRIMEIRO_DESEMBOLSO')

def to_datetime_b(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna],format='%Y')

to_datetime_b(df_proj_fsa_desemb_clean, 'ANO_CHAMADA_PUBLICA')


def to_datetime_c(df, coluna, date_format):
    df[coluna] = pd.to_datetime(df[coluna], format=date_format)

to_datetime_c(df_proj_fsa_desemb_clean, 'DT_PUBLICACAO_CONTRATO_DOU', '%Y-%m-%d')

#Preenchendo valores nulos na copluna DT_PRIMEIRO_DESEMBOLSO com a média = 37 dias

df_proj_fsa_desemb_clean_time = df_proj_fsa_desemb_clean.dropna()
df_proj_fsa_desemb_clean_time['TEMPO_DESEMBOLSO'] = df_proj_fsa_desemb_clean['DT_PUBLICACAO_CONTRATO_DOU'] - df_proj_fsa_desemb_clean['DT_PRIMEIRO_DESEMBOLSO']
mean = df_proj_fsa_desemb_clean_time['TEMPO_DESEMBOLSO'].mean()

def to_datetime_a(df, coluna,coluna2):
    df[coluna] = df[coluna].fillna(pd.to_datetime(df[coluna2])+ pd.DateOffset(day=37))

to_datetime_a(df_proj_fsa_desemb_clean, 'DT_PRIMEIRO_DESEMBOLSO', 'DT_PUBLICACAO_CONTRATO_DOU')

df_proj_fsa_desemb = df_proj_fsa_desemb_clean

df_proj_fsa_desemb_es = pd.DataFrame(columns=df_proj_fsa_desemb.columns)

for cnpj in cnpjs_to_check:
    matching_rows = df_proj_fsa_desemb[df_proj_fsa_desemb['CNPJ_PROPONENTE'].str.contains(cnpj)]
    df_proj_fsa_desemb_es = pd.concat([df_proj_fsa_desemb_es, matching_rows])

df_proj_fsa_desemb_es.reset_index(drop=True, inplace=True)

# to replace
def replace(df, coluna, old_value, new_value):
    df[coluna].replace(old_value, new_value, inplace=True)

replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 11', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 02', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 03', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 05', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'SAV/MINC 07', 'SAV/MINC')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODECINE 04', 'PRODECINE')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODECINE 05', 'PRODECINE')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODECINE 01', 'PRODECINE')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODAV 05', 'PRODAV')
replace(df_proj_fsa_desemb_es, 'CHAMADA_PUBLICA', 'PRODAV - TVS PÚBLICAS', 'PRODAV')

df_proj_fsa_desemb_es['VL_CONTRATO_DOU'] = df_proj_fsa_desemb_es['VL_CONTRATO_DOU'].replace(',', '.')
df_proj_fsa_desemb_es['VL_TOTAL_LIBERADO'] = df_proj_fsa_desemb_es['VL_TOTAL_LIBERADO'].replace(',', '.')

df_proj_fsa_desemb_es
# Out:
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3375510902.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna] = pd.to_datetime(df[coluna], dayfirst=True, errors='coerce')
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3375510902.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna] = pd.to_datetime(df[coluna],format='%Y')
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3375510902.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna] = pd.to_datetime(df[coluna], format=date_format)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3375510902.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_proj_fsa_desemb_clean_time['TEMPO_DESEMBOLSO'] = df_proj_fsa_desemb_clean['DT_PUBLICACAO_CONTRATO_DOU'] - df_proj_fsa_desemb_clean['DT_PRIMEIRO_DESEMBOLSO']
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3375510902.py:35: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex.
#   df[coluna] = df[coluna].fillna(pd.to_datetime(df[coluna2])+ pd.DateOffset(day=37))
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\3375510902.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna] = df[coluna].fillna(pd.to_datetime(df[coluna2])+ pd.DateOffset(day=37))
#    IDENTIFICACAO_CONTRATO                                     TITULO_PROJETO
# 0               PR-03.624                                                NaN  \
# 1               DG-01.106           HABITAÇÃO SOCIAL - PROJETOS DE UM BRASIL
# 2               PR-02.610                              OS PRIMEIROS SOLDADOS
# 3               PR-02.351                  25º FESTIVAL DE CINEMA DE VITÓRIA
# 4               PR-02.838                  26º FESTIVAL DE CINEMA DE VITÓRIA
# 5               PR-02.298  4º CINE.EMA - FESTIVAL DE CINEMA AMBIENTAL DO ...
# 6               PR-02.303  7º FECIN - FESTIVAL DE TV E CINEMA DO INTERIOR...
# 7               PR-03.439  O PALHAÇO MENINO - MEMÓRIAS DE UM MENINO MASCA...
# 8               PR-03.440  PÁSSARO DE PAPEL - A JORNADA DE JAIMINHO E SUA...
# 9               DG-00.912                                              DIDI
# 10              PR-02.655                              TODA NOITE ESTAREI LÁ
# 11              DG-00.870                                DESTINO DAS SOMBRAS
# 12              PR-02.732                                DESTINO DAS SOMBRAS
# 13              DG-01.786                                             A SUGA
# 14              PR-03.646                                                NaN
# 15              PR-01.875                                  OS INCONTESTÁVEIS
# 16              PR-02.843                                           PRESENÇA
# 17              PR-03.715                                                NaN
# 18              PR-03.788                                               ÁRIA
# 19              PR-03.830                                           PALALOOS
# 20              PR-03.678                                                NaN
# 21              DG-00.880                                         MATA NEGRA
# 22              PR-01.934                     O CEMITÉRIO DAS ALMAS PERDIDAS
# 23              PR-01.960                     O CEMITÉRIO DAS ALMAS PERDIDAS
# 24              PR-02.688                                       A MATA NEGRA
# 25              PR-03.687                                                NaN
# 26              PR-02.215                                   VIAGEM À XIBALBÁ
# 27              PR-03.473                                    GAROTAS DO GAME
# 28              DG-00.513                                       ZORA CURIOSA
# 29              PR-03.089  FESTIVAL BESIDES THE SCREEN 2019 - INTELIGÊNCI...
# 30              PR-03.757                                                NaN
# 31              PR-03.682                                                NaN
# 32             FSA-59.951                                                NaN
#
#                                       CHAMADA_PUBLICA ANO_CHAMADA_PUBLICA
# 0   PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...          2020-01-01  \
# 1                                           PRODAV 11          2015-01-01
# 2                                  ARRANJOS REGIONAIS          2017-01-01
# 3                                            SAV/MINC          2018-01-01
# 4                                            SAV/MINC          2018-01-01
# 5                                            SAV/MINC          2018-01-01
# 6                                            SAV/MINC          2018-01-01
# 7                                            SAV/MINC          2018-01-01
# 8                                            SAV/MINC          2018-01-01
# 9                                  ARRANJOS REGIONAIS          2014-01-01
# 10                                 ARRANJOS REGIONAIS          2017-01-01
# 11                                 ARRANJOS REGIONAIS          2014-01-01
# 12                                          PRODECINE          2013-01-01
# 13                                 ARRANJOS REGIONAIS          2015-01-01
# 14  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...          2020-01-01
# 15                                 ARRANJOS REGIONAIS          2015-01-01
# 16                                 ARRANJOS REGIONAIS          2017-01-01
# 17  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...          2020-01-01
# 18                                           SAV/MINC          2018-01-01
# 19                                             PRODAV          2018-01-01
# 20  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...          2020-01-01
# 21                                          PRODECINE          2014-01-01
# 22                                 ARRANJOS REGIONAIS          2015-01-01
# 23                                          PRODECINE          2016-01-01
# 24                          COMERCIALIZAÇÃO EM CINEMA          2018-01-01
# 25  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...          2020-01-01
# 26                                             PRODAV          2016-01-01
# 27                                           SAV/MINC          2018-01-01
# 28                                          PRODAV 11          2014-01-01
# 29                                           SAV/MINC          2018-01-01
# 30  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...          2020-01-01
# 31  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...          2020-01-01
# 32                            CRÉDITO EMERGENCIAL FSA          2020-01-01
#
#        CNPJ_PROPONENTE                            RAZAO_SOCIAL_PROPONENTE
# 0   10.763.360/0001-07      CEC - CENTRO DE ENTRETENIMENTO CONCEIÇÃO LTDA  \
# 1   14.210.788/0001-75                 PIQUE-BANDEIRA PRODUCOES LTDA - ME
# 2   14.210.788/0001-75                 PIQUE-BANDEIRA PRODUCOES LTDA - ME
# 3   02.616.581/0001-16       GALPÃO PRODUÇÕES ARTÍSTICAS E CULTURAIS LTDA
# 4   02.616.581/0001-16       GALPÃO PRODUÇÕES ARTÍSTICAS E CULTURAIS LTDA
# 5   04.585.783/0001-73                            CAJU PRODUÇOES LTDA- ME
# 6   04.585.783/0001-73                            CAJU PRODUÇOES LTDA- ME
# 7   04.585.783/0001-73                            CAJU PRODUÇOES LTDA- ME
# 8   04.585.783/0001-73                            CAJU PRODUÇOES LTDA- ME
# 9   08.103.899/0001-80            LÚMEN PRODUÇÕES AUDIOVISUAIS LTDA. - ME
# 10  08.103.899/0001-80            LÚMEN PRODUÇÕES AUDIOVISUAIS LTDA. - ME
# 11  18.589.962/0001-93             FINORDIA PRODUÇÕES CULTURAIS LTDA - ME
# 12  18.589.962/0001-93             FINORDIA PRODUÇÕES CULTURAIS LTDA - ME
# 13  21.710.727/0001-32                                   SIZENANDO FILMES
# 14  17.151.166/0001-01                               CINE SÃO MATEUS LTDA
# 15  18.580.137/0001-28                LADART PRODUÇÕES E CONSULTORIA LTDA
# 16  18.580.137/0001-28                LADART PRODUÇÕES E CONSULTORIA LTDA
# 17  04.769.554/0001-09                     GMZ EMPRESA DE CINEMAS LTDA ME
# 18  14.635.446/0001-05  EYE MOVE ESTUDIO DE ANIMACAO E ILUSTRACAO LTDA...
# 19  14.635.446/0001-05  EYE MOVE ESTUDIO DE ANIMACAO E ILUSTRACAO LTDA...
# 20  21.033.878/0001-01                    CINEMATOGRAFICA ARACRUZ LTDA ME
# 21  09.369.796/0001-29          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 22  09.369.796/0001-29          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 23  09.369.796/0001-29          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 24  09.369.796/0001-29          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 25  19.387.261/0001-34                         CINEMATOGRÁFICA PIÚMA LTDA
# 26  14.128.876/0001-22    HORIZONTE LÍQUIDO PRODUÇÕES CULTURAIS LTDA - ME
# 27  14.128.876/0001-22    HORIZONTE LÍQUIDO PRODUÇÕES CULTURAIS LTDA - ME
# 28  21.681.140/0001-42               VENTANIA PRODUÇÕES AUDIOVISUAIS LTDA
# 29  21.681.140/0001-42               VENTANIA PRODUÇÕES AUDIOVISUAIS LTDA
# 30  31.703.432/0001-92                     R. F. R. GOMES CINEMATOGRAFICA
# 31  05.077.549/0001-06                     CINEMATOGRÁFICA GUARAPARI LTDA
# 32  05.077.549/0001-06                     CINEMATOGRÁFICA GUARAPARI LTDA
#
#                                RAZAO_SOCIAL_PRODUTORA
# 0                                       SEM PRODUTORA  \
# 1                  PIQUE-BANDEIRA PRODUCOES LTDA - ME
# 2                  PIQUE-BANDEIRA PRODUCOES LTDA - ME
# 3                                       SEM PRODUTORA
# 4                                       SEM PRODUTORA
# 5                                       SEM PRODUTORA
# 6                                       SEM PRODUTORA
# 7                             CAJU PRODUÇOES LTDA- ME
# 8                             CAJU PRODUÇOES LTDA- ME
# 9             LÚMEN PRODUÇÕES AUDIOVISUAIS LTDA. - ME
# 10            LÚMEN PRODUÇÕES AUDIOVISUAIS LTDA. - ME
# 11             FINORDIA PRODUÇÕES CULTURAIS LTDA - ME
# 12             FINORDIA PRODUÇÕES CULTURAIS LTDA - ME
# 13                                   SIZENANDO FILMES
# 14                                      SEM PRODUTORA
# 15                LADART PRODUÇÕES E CONSULTORIA LTDA
# 16                LADART PRODUÇÕES E CONSULTORIA LTDA
# 17                                      SEM PRODUTORA
# 18  EYE MOVE ESTUDIO DE ANIMACAO E ILUSTRACAO LTDA...
# 19  EYE MOVE ESTUDIO DE ANIMACAO E ILUSTRACAO LTDA...
# 20                                      SEM PRODUTORA
# 21          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 22          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 23          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 24          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 25                                      SEM PRODUTORA
# 26    HORIZONTE LÍQUIDO PRODUÇÕES CULTURAIS LTDA - ME
# 27    HORIZONTE LÍQUIDO PRODUÇÕES CULTURAIS LTDA - ME
# 28               VENTANIA PRODUÇÕES AUDIOVISUAIS LTDA
# 29                                      SEM PRODUTORA
# 30                                      SEM PRODUTORA
# 31                                      SEM PRODUTORA
# 32                                      SEM PRODUTORA
#
#               RAZAO_SOCIAL_DISTRIBUIDORA_PROGRAMADORA
# 0                      SEM DISTRIBUIDORA/PROGRAMADORA  \
# 1                      SEM DISTRIBUIDORA/PROGRAMADORA
# 2                  PIQUE-BANDEIRA PRODUCOES LTDA - ME
# 3                      SEM DISTRIBUIDORA/PROGRAMADORA
# 4                      SEM DISTRIBUIDORA/PROGRAMADORA
# 5                      SEM DISTRIBUIDORA/PROGRAMADORA
# 6                      SEM DISTRIBUIDORA/PROGRAMADORA
# 7                      SEM DISTRIBUIDORA/PROGRAMADORA
# 8                             CAJU PRODUÇOES LTDA- ME
# 9             LÚMEN PRODUÇÕES AUDIOVISUAIS LTDA. - ME
# 10            LÚMEN PRODUÇÕES AUDIOVISUAIS LTDA. - ME
# 11                         MORO COMUNICAÇÃO EIRELI-ME
# 12                         MORO COMUNICAÇÃO EIRELI-ME
# 13                                   SIZENANDO FILMES
# 14                     SEM DISTRIBUIDORA/PROGRAMADORA
# 15         LIVRES DISTRIBUIDORA DE AUDIVISUAL LTDA ME
# 16                LADART PRODUÇÕES E CONSULTORIA LTDA
# 17                     SEM DISTRIBUIDORA/PROGRAMADORA
# 18  EYE MOVE ESTUDIO DE ANIMACAO E ILUSTRACAO LTDA...
# 19                     SEM DISTRIBUIDORA/PROGRAMADORA
# 20                     SEM DISTRIBUIDORA/PROGRAMADORA
# 21          FÁBULAS NEGRAS PRODUÇÕES ARTÍSTICAS LTDA.
# 22                         MORO COMUNICAÇÃO EIRELI-ME
# 23                         MORO COMUNICAÇÃO EIRELI-ME
# 24                      ELO AUDIOVISUAL SERVIÇOS LTDA
# 25                     SEM DISTRIBUIDORA/PROGRAMADORA
# 26                     SEM DISTRIBUIDORA/PROGRAMADORA
# 27    HORIZONTE LÍQUIDO PRODUÇÕES CULTURAIS LTDA - ME
# 28                     SEM DISTRIBUIDORA/PROGRAMADORA
# 29                     SEM DISTRIBUIDORA/PROGRAMADORA
# 30                     SEM DISTRIBUIDORA/PROGRAMADORA
# 31                     SEM DISTRIBUIDORA/PROGRAMADORA
# 32                     SEM DISTRIBUIDORA/PROGRAMADORA
#
#    DT_PUBLICACAO_CONTRATO_DOU  VL_CONTRATO_DOU DT_PRIMEIRO_DESEMBOLSO
# 0                  2020-12-17         42692.10             2020-12-22  \
# 1                  2016-12-05       1014000.00             2017-01-18
# 2                  2018-11-28        900000.00             2018-12-03
# 3                  2018-08-22        200000.01             2018-08-28
# 4                  2019-02-27        300000.00             2019-03-08
# 5                  2018-08-15        100000.00             2018-08-20
# 6                  2018-08-15        160000.00             2018-08-20
# 7                  2020-02-27        100000.00             2020-03-12
# 8                  2020-02-27        999999.00             2020-03-12
# 9                  2016-09-30        150000.00             2016-11-03
# 10                 2018-12-12        180000.00             2018-12-17
# 11                 2016-09-02        600000.00             2016-09-09
# 12                 2019-01-23         88773.26             2019-01-28
# 13                 2017-12-13        180000.00             2017-12-18
# 14                 2020-12-02         21346.06             2020-12-21
# 15                 2018-01-24         75000.00             2018-01-30
# 16                 2019-02-27        180000.00             2019-03-08
# 17                 2020-12-02         34153.69             2020-12-21
# 18                 2020-12-02        350000.00             2020-12-04
# 19                 2021-01-20       1200000.00             2021-01-31
# 20                 2020-12-02         34153.69             2020-12-31
# 21                 2016-09-21        629061.00             2016-09-28
# 22                 2018-03-07        600000.00             2018-03-12
# 23                 2018-03-07       1100000.00             2018-03-12
# 24                 2019-02-27        122100.00             2019-03-21
# 25                 2020-11-11         21346.06             2020-11-13
# 26                 2018-07-11        150000.00             2018-07-23
# 27                 2020-03-11        500000.00             2020-03-23
# 28                 2015-12-23        162000.00             2016-02-05
# 29                 2019-06-27        175000.00             2019-07-02
# 30                 2020-11-18         21346.06             2020-12-09
# 31                 2021-01-13         42692.10             2021-01-31
# 32                 2021-01-27        100000.00             2021-01-31
#
#     VL_TOTAL_LIBERADO
# 0            42692.10
# 1          1014000.00
# 2           900000.00
# 3           200000.01
# 4           300000.00
# 5           100000.00
# 6           160000.00
# 7           100000.00
# 8           999999.00
# 9           150000.00
# 10          180000.00
# 11          600000.00
# 12           88773.26
# 13          180000.00
# 14           21346.06
# 15           75000.00
# 16          180000.00
# 17           34153.69
# 18          350000.00
# 19               0.00
# 20               0.00
# 21          629061.00
# 22          600000.00
# 23         1100000.00
# 24          122100.00
# 25           21346.06
# 26          150000.00
# 27          500000.00
# 28          162000.00
# 29          175000.00
# 30           21346.06
# 31               0.00
# 32               0.00

# %% [markdown]
# ---

# %% [markdown]
# ### Projetos de Renúncia Fiscal

# %%
df_proj_renun_fisc = pd.read_csv('ProjetosRenunciaFiscal.csv')
df_proj_renun_fisc.head(5)
df_proj_renun_fisc_clean = df_proj_renun_fisc[['SALIC', 'TITULO_PROJETO', 'UF_PROPONENTE',
       'SITUACAO_REGISTRO', 'CNPJ_PROPONENTE', 'RAZAO_SOCIAL_PROPONENTE',
       'LEI_8313', 'ART1', 'ART1A', 'ART3', 'ART3A', 'ART39', 'FUNCINES',
       'TOTAL_CAPTADO', 'DT_APROVACAO_CAPTACAO', 'DT_1_LIBERACAO']]

def to_datetime(df, coluna):
    df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)

to_datetime(df_proj_renun_fisc_clean, 'DT_1_LIBERACAO')
to_datetime(df_proj_renun_fisc_clean, 'DT_APROVACAO_CAPTACAO')

def to_datetime_b(df, coluna):
    df['ANO_APROVACAO'] = pd.to_datetime(df[coluna],format='%Y-%m-%d').dt.year


to_datetime_b(df_proj_renun_fisc_clean, 'DT_APROVACAO_CAPTACAO')


df_proj_renun_fisc = df_proj_renun_fisc_clean


df_proj_renun_fisc_es = df_proj_renun_fisc[df_proj_renun_fisc['UF_PROPONENTE'] == 'ES']

df_proj_renun_fisc_es
# Out:
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\1876037991.py:9: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\1876037991.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\1876037991.py:9: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\1876037991.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna] = pd.to_datetime(df[coluna], dayfirst=True)
#         SALIC                                     TITULO_PROJETO
# 316   12-0516                                             HELENA  \
# 602   07-0279                                       Outro Sertão
# 2088  17-0202  A Incrível Jornada - A História das Baleias Ca...
# 2352  10-0407                                             Punhal
# 2353  97-0586                        Morte da Mulata (A) - Filme
# 2400  02-4052  A Rebelião dos Estudantes      (Ex - Rebelião ...
#
#      UF_PROPONENTE SITUACAO_REGISTRO     CNPJ_PROPONENTE
# 316             ES         IRREGULAR  01.592.538/0001-03  \
# 602             ES          DEFERIDO  02.616.581/0001-16
# 2088            ES          DEFERIDO  18.589.962/0001-93
# 2352            ES          DEFERIDO  31.478.621/0001-09
# 2353            ES          DEFERIDO  31.478.621/0001-09
# 2400            ES         IRREGULAR  36.300.499/0001-08
#
#                            RAZAO_SOCIAL_PROPONENTE  LEI_8313      ART1
# 316         RMS PRODUÇÕES CINEMATOGRÁFICAS LTDA-ME       0.0  484749.0  \
# 602   GALPÃO PRODUÇÕES ARTÍSTICAS E CULTURAIS LTDA       0.0       0.0
# 2088        FINORDIA PRODUÇÕES CULTURAIS LTDA - ME       0.0       0.0
# 2352            VERVE PRODUÇÕES E CONSULTORIA LTDA       0.0  266500.0
# 2353            VERVE PRODUÇÕES E CONSULTORIA LTDA       0.0  188390.0
# 2400          PRO TEXTO COMUNICAÇÃO E CULTURA LTDA  238550.0       0.0
#
#           ART1A  ART3  ART3A  ART39  FUNCINES  TOTAL_CAPTADO
# 316        0.00   0.0    0.0    0.0       0.0      484749.00  \
# 602   949827.59   0.0    0.0    0.0       0.0      949827.59
# 2088  550474.36   0.0    0.0    0.0       0.0      550474.36
# 2352   40000.00   0.0    0.0    0.0       0.0      306500.00
# 2353       0.00   0.0    0.0    0.0       0.0      188390.00
# 2400       0.00   0.0    0.0    0.0       0.0      238550.00
#
#      DT_APROVACAO_CAPTACAO DT_1_LIBERACAO  ANO_APROVACAO
# 316             2013-01-07     2018-09-17           2013
# 602             2007-10-22     2008-01-15           2007
# 2088            2017-06-02     2018-03-28           2017
# 2352            2010-12-08     2011-08-10           2010
# 2353            1996-11-29     2000-06-13           1996
# 2400            2002-11-26     2006-02-06           2002

# %% [markdown]
# ---

# %% [markdown]
# ### Atividade Econômica dos Agentes

# %%
df_ativi_econ_agent_regis = pd.read_csv('AtividadesEconomicasDosAgentesRegistrados.csv', encoding='utf-8', sep=',')

df_ativi_econ_agent_regis_es = df_ativi_econ_agent_regis[df_ativi_econ_agent_regis['CNPJ'].apply(lambda x: x in cnpjs_to_check)]

df_ativi_econ_agent_regis_es
# Out:
#         REGISTRO_ANCINE                                       RAZAO_SOCIAL
# 520               11776       GALPÃO PRODUÇÕES ARTÍSTICAS E CULTURAIS LTDA  \
# 521               11776       GALPÃO PRODUÇÕES ARTÍSTICAS E CULTURAIS LTDA
# 857               12199                                          E.R.TOSTA
# 858               12199                                          E.R.TOSTA
# 859               12199                                          E.R.TOSTA
# ...                 ...                                                ...
# 105110             5361  INSTITUTO DE DESENVOLVIMENTO SOCIAL E GESTÃO D...
# 105111             5361  INSTITUTO DE DESENVOLVIMENTO SOCIAL E GESTÃO D...
# 105112             5361  INSTITUTO DE DESENVOLVIMENTO SOCIAL E GESTÃO D...
# 105113             5361  INSTITUTO DE DESENVOLVIMENTO SOCIAL E GESTÃO D...
# 105261             5511                        JANE MARY E ASSOCIADOS LTDA
#
#                       CNPJ                                ATIVIDADE_ECONOMICA
# 520     02.616.581/0001-16  Artes cênicas, espetáculos e atividades comple...  \
# 521     02.616.581/0001-16  Atividades de produção cinematográfica, de víd...
# 857     03.692.683/0001-83                            Agências de publicidade
# 858     03.692.683/0001-83                   Produção de espetáculos de dança
# 859     03.692.683/0001-83                Produção de filmes para publicidade
# ...                    ...                                                ...
# 105110  03.132.906/0001-58  Atividades associativas não especificadas ante...
# 105111  03.132.906/0001-58  Atividades de associações de defesa de direito...
# 105112  03.132.906/0001-58  Atividades de organizações associativas ligada...
# 105113  03.132.906/0001-58  Atividades de pós-produção cinematográfica, de...
# 105261  03.172.036/0001-40                            Agências de publicidade
#
#        CLASSIFICACAO_ATIVIDADE
# 520                  PRINCIPAL
# 521                 SECUNDARIA
# 857                  PRINCIPAL
# 858                 SECUNDARIA
# 859                 SECUNDARIA
# ...                        ...
# 105110              SECUNDARIA
# 105111              SECUNDARIA
# 105112              SECUNDARIA
# 105113              SECUNDARIA
# 105261               PRINCIPAL
#
# [2057 rows x 5 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Grupos Econômicos

# %%
df_grupos_econ = pd.read_csv('GruposEconomicos.csv', encoding='utf-8', sep=',')

df_grupos_econ_es = df_grupos_econ[df_grupos_econ['CNPJ_EMPRESA'].apply(lambda x: x in cnpjs_to_check)]

df_grupos_econ_es
# Out:
#       REGISTRO_ANCINE        CNPJ_EMPRESA
# 46              41941  32.243.334/0001-82  \
# 139             42163  13.546.570/0001-23
# 273             50705  42.856.251/0001-12
# 490             24231  18.012.019/0001-13
# 492              5252  05.077.549/0001-06
# 552             19578  10.763.360/0001-07
# 652             51753  12.530.623/0001-55
# 721              5252  05.077.549/0001-06
# 832              5252  05.077.549/0001-06
# 876             46519  05.804.377/0001-17
# 992             49084  30.428.516/0001-00
# 1116            47716  04.201.181/0001-75
# 1326            47388  25.912.530/0001-37
# 1483             2570  01.915.175/0001-91
# 1497            24025  17.151.166/0001-01
# 1686            29417  19.387.261/0001-34
# 1729            37267  04.585.783/0001-73
# 1775            24384  12.379.149/0001-02
# 1884             5361  03.132.906/0001-58
# 1894            21894  14.992.876/0001-76
# 2253            50002  32.992.475/0001-06
# 2430            51713  46.850.630/0001-56
# 2746            29417  19.387.261/0001-34
# 2851            50159  42.128.343/0001-86
# 2925            29417  19.387.261/0001-34
# 2935            51838  29.621.500/0001-22
# 3122            42988  32.719.785/0001-43
# 3150            50754  43.380.531/0001-60
# 3242            25427  18.670.862/0001-97
# 3328            17645  12.301.061/0001-78
# 3377            52430  37.281.569/0001-82
# 3399            23438  11.982.842/0001-02
# 3470            44482  16.877.661/0001-30
# 3973            47524  39.341.953/0001-59
# 4026             5252  05.077.549/0001-06
# 4056            32420  21.033.878/0001-01
# 4071            32420  21.033.878/0001-01
# 4326             5252  05.077.549/0001-06
# 4493             5252  05.077.549/0001-06
# 4677             5511  03.172.036/0001-40
# 4795            24025  17.151.166/0001-01
# 4854            25580  16.806.723/0001-12
# 4864            24231  18.012.019/0001-13
# 5071            11776  02.616.581/0001-16
# 5476            29417  19.387.261/0001-34
# 5523            24025  17.151.166/0001-01
# 5564             5252  05.077.549/0001-06
# 5671            50754  43.380.531/0001-60
# 5684            51713  46.850.630/0001-56
# 6115            32420  21.033.878/0001-01
#
#                                            RAZAO_SOCIAL
# 46                                      J G MELO JUNIOR  \
# 139                                   HEMERSON SALVADOR
# 273                         MARIA MARIA MULTIMÍDIA LTDA
# 490                 CINEMAGIC VITORIA CINEMAS LTDA - ME
# 492                      CINEMATOGRÁFICA GUARAPARI LTDA
# 552       CEC - CENTRO DE ENTRETENIMENTO CONCEIÇÃO LTDA
# 652                                     BRASIL POSITIVO
# 721                      CINEMATOGRÁFICA GUARAPARI LTDA
# 832                      CINEMATOGRÁFICA GUARAPARI LTDA
# 876                SALVADOR AGENCIA DE PUBLICIDADE LTDA
# 992                           PAULA G VAREJAO PRODUCOES
# 1116  ASSOCIAÇÃO CULTURAL CIRCENSE E AMBIENTAL UMA F...
# 1326                                 SONORA FILMES LTDA
# 1483      TAKE1 PUBLICIDADE PROPAGANDA E MARKETING LTDA
# 1497                               CINE SÃO MATEUS LTDA
# 1686                         CINEMATOGRÁFICA PIÚMA LTDA
# 1729                            CAJU PRODUÇOES LTDA- ME
# 1775                                   H C M DOS SANTOS
# 1884  INSTITUTO DE DESENVOLVIMENTO SOCIAL E GESTÃO D...
# 1894                       AUDIO VISUAL EDIÇÕES LTDA ME
# 2253                             R COUTINHO FILMES LTDA
# 2430                     EYE SLICE PICTURES BRASIL LTDA
# 2746                         CINEMATOGRÁFICA PIÚMA LTDA
# 2851                                    S.M. GOMES LTDA
# 2925                         CINEMATOGRÁFICA PIÚMA LTDA
# 2935                                   COMBOIO ART LTDA
# 3122                                BLACK VIDEO LTDA ME
# 3150                          ENCANTADA PRODUÇÕES LTDA.
# 3242                           KASACA PRODUÇÕES LTDA ME
# 3328                       TK 1 VIDEO PRODUÇÕES LTDA ME
# 3377                       L.A. FERREIRA PRODUCOES LTDA
# 3399                      MEGA COMERCIO E SERVIÇOS LTDA
# 3470             ADRIANA GUIMARÃES JACOBSEN 01739876725
# 3973                   RATIMBUM PRODUÇÕES DE ARTES LTDA
# 4026                     CINEMATOGRÁFICA GUARAPARI LTDA
# 4056                    CINEMATOGRAFICA ARACRUZ LTDA ME
# 4071                    CINEMATOGRAFICA ARACRUZ LTDA ME
# 4326                     CINEMATOGRÁFICA GUARAPARI LTDA
# 4493                     CINEMATOGRÁFICA GUARAPARI LTDA
# 4677                        JANE MARY E ASSOCIADOS LTDA
# 4795                               CINE SÃO MATEUS LTDA
# 4854                CORUJAS PRODUÇÃO DE FILMES LTDA-EPP
# 4864                CINEMAGIC VITORIA CINEMAS LTDA - ME
# 5071       GALPÃO PRODUÇÕES ARTÍSTICAS E CULTURAIS LTDA
# 5476                         CINEMATOGRÁFICA PIÚMA LTDA
# 5523                               CINE SÃO MATEUS LTDA
# 5564                     CINEMATOGRÁFICA GUARAPARI LTDA
# 5671                          ENCANTADA PRODUÇÕES LTDA.
# 5684                     EYE SLICE PICTURES BRASIL LTDA
# 6115                    CINEMATOGRAFICA ARACRUZ LTDA ME
#
#                                       EMPRESA_ASSOCIADA CNPJ_EMPRESA_ASSOCIADA
# 46                JOSE GRACILDO MELO JUNIOR 09627706710     14.252.772/0001-25
# 139                SALVADOR AGENCIA DE PUBLICIDADE LTDA     05.804.377/0001-17
# 273                     C3 COMUNICAÇÃO E MARKETING LTDA     01.936.260/0001-36
# 490                           CRYK CINEMA ARARUAMA LTDA     12.991.031/0001-30
# 492                          CINEMATOGRÁFICA PIÚMA LTDA     19.387.261/0001-34
# 552                                 MARIN & ARMANI LTDA     01.862.774/0001-94
# 652                     WDESIGNER CORPORATION LTDA - ME     13.050.466/0001-43
# 721                     CINEMATOGRAFICA BOITUVA LTDA ME     21.528.711/0001-03
# 832                 CINEMATOGRÁFICA CATAGUASES LTDA EPP     21.257.121/0001-93
# 876                                   HEMERSON SALVADOR     13.546.570/0001-23
# 992   EDMILSON VAREJÃO CONSULTORIA E SERVIÇOS LTDA - ME     17.067.157/0001-37
# 1116                   RATIMBUM PRODUÇÕES DE ARTES LTDA     39.341.953/0001-59
# 1326                       L.K DE CASTRO PRODUCOES LTDA     41.148.392/0001-18
# 1483                       TK 1 VIDEO PRODUÇÕES LTDA ME     12.301.061/0001-78
# 1497                    CINEMATOGRAFICA BOITUVA LTDA ME     21.528.711/0001-03
# 1686                     CINEMATOGRÁFICA GUARAPARI LTDA     05.077.549/0001-06
# 1729                       L.A. FERREIRA PRODUCOES LTDA     37.281.569/0001-82
# 1775                              VITORIA FILMES EIRELI     28.497.273/0001-02
# 1884             ADRIANA GUIMARÃES JACOBSEN 01739876725     16.877.661/0001-30
# 1894                           KASACA PRODUÇÕES LTDA ME     18.670.862/0001-97
# 2253                            COMMUNIC FILMES LTDA ME     22.402.331/0001-90
# 2430                          ALEF FILMS PRODUCOES LTDA     18.329.398/0001-70
# 2746                  CINEMATOGRÁFICA CACHOEIRO LTDA ME     04.736.746/0001-19
# 2851               TOWER WEB SOLUÇÕES DE INTERNET LTDA.     10.603.283/0001-10
# 2925                       VIA SUL CINEMATOGRÁFICA LTDA     08.537.690/0001-24
# 2935                            RAYAN FABBRI CASAGRANDE     26.454.482/0001-43
# 3122              CROMA PRODUÇÕES AUDIOVISUAIS LTDA EPP     00.779.279/0001-53
# 3150                          ALEF FILMS PRODUCOES LTDA     18.329.398/0001-70
# 3242                     AUDIO VISUAL EDIÇÕES LTDA - ME     14.992.876/0001-76
# 3328      TAKE1 PUBLICIDADE PROPAGANDA E MARKETING LTDA     01.915.175/0001-91
# 3377                            CAJU PRODUÇOES LTDA- ME     04.585.783/0001-73
# 3399                        JANE MARY E ASSOCIADOS LTDA     03.172.036/0001-40
# 3470  INSTITUTO DE DESENVOLVIMENTO SOCIAL E GESTÃO D...     03.132.906/0001-58
# 3973  ASSOCIAÇÃO CULTURAL CIRCENSE E AMBIENTAL UMA F...     04.201.181/0001-75
# 4026                    CINEMATOGRAFICA ARACRUZ LTDA ME     21.033.878/0001-01
# 4056                     CINEMATOGRÁFICA GUARAPARI LTDA     05.077.549/0001-06
# 4071                               CINE SÃO MATEUS LTDA     17.151.166/0001-01
# 4326                  CINEMATOGRÁFICA CACHOEIRO LTDA ME     04.736.746/0001-19
# 4493                       VIA SUL CINEMATOGRÁFICA LTDA     08.537.690/0001-24
# 4677                      MEGA COMERCIO E SERVIÇOS LTDA     11.982.842/0001-02
# 4795                     CINEMATOGRÁFICA GUARAPARI LTDA     05.077.549/0001-06
# 4854              IMMAGINARE ARTE TÉCNICA EM VÍDEO LTDA     04.595.334/0001-06
# 4864                            CRYK CINEMA BACAXA LTDA     35.282.350/0001-72
# 5071          INSTITUTO BRASIL DE CULTURA E ARTE - IBCA     11.474.955/0001-05
# 5476                CINEMATOGRÁFICA CATAGUASES LTDA EPP     21.257.121/0001-93
# 5523                    CINEMATOGRAFICA ARACRUZ LTDA ME     21.033.878/0001-01
# 5564                               CINE SÃO MATEUS LTDA     17.151.166/0001-01
# 5671                     EYE SLICE PICTURES BRASIL LTDA     46.850.630/0001-56
# 5684                          ENCANTADA PRODUÇÕES LTDA.     43.380.531/0001-60
# 6115                    CINEMATOGRAFICA BOITUVA LTDA ME     21.528.711/0001-03

# %% [markdown]
# ---

# %% [markdown]
# ### Salas de Exibição e Complexos

# %%
df_salas_exib = pd.read_csv('SalasDeExibicaoEComplexos.csv', encoding='utf-8', sep=',')

df_salas_exib_es = df_salas_exib[df_salas_exib['UF_COMPLEXO'] == 'ES']

df_salas_exib_es.head(5)
# Out:
#                                  NOME_SALA  REGISTRO_SALA           CNPJ_SALA
# 11  CINESERCLA SHOPPING MONTSERRAT SALA 01        5004768  03.879.383/0005-31  \
# 12  CINESERCLA SHOPPING MONTSERRAT SALA 02        5004764  03.879.383/0005-31
# 13  CINESERCLA SHOPPING MONTSERRAT SALA 03        5004767  03.879.383/0005-31
# 14  CINESERCLA SHOPPING MONTSERRAT SALA 04        5004765  03.879.383/0005-31
# 15  CINESERCLA SHOPPING MONTSERRAT SALA 05        5004766  03.879.383/0005-31
#
#        SITUACAO_SALA  ASSENTOS_SALA                   NOME_COMPLEXO
# 11  EM FUNCIONAMENTO            225  CINESERCLA SHOPPING MONTSERRAT  \
# 12  EM FUNCIONAMENTO            263  CINESERCLA SHOPPING MONTSERRAT
# 13  EM FUNCIONAMENTO            159  CINESERCLA SHOPPING MONTSERRAT
# 14  EM FUNCIONAMENTO            173  CINESERCLA SHOPPING MONTSERRAT
# 15  EM FUNCIONAMENTO            157  CINESERCLA SHOPPING MONTSERRAT
#
#     REGISTRO_COMPLEXO PAGINA_ELETRONICA_COMPLEXO
# 11              27434             SEM INFORMAÇÃO  \
# 12              27434             SEM INFORMAÇÃO
# 13              27434             SEM INFORMAÇÃO
# 14              27434             SEM INFORMAÇÃO
# 15              27434             SEM INFORMAÇÃO
#
#                   ENDERECO_COMPLEXO  NUMERO_ENDERECO_COMPLEXO  ...
# 11  Avenida Eldes Scherrer de Souza                      2162  ...  \
# 12  Avenida Eldes Scherrer de Souza                      2162  ...
# 13  Avenida Eldes Scherrer de Souza                      2162  ...
# 14  Avenida Eldes Scherrer de Souza                      2162  ...
# 15  Avenida Eldes Scherrer de Souza                      2162  ...
#
#    MUNICIPIO_COMPLEXO CEP_COMPLEXO UF_COMPLEXO COMPLEXO_ITINERANTE
# 11              SERRA    29167-080          ES                 NÃO  \
# 12              SERRA    29167-080          ES                 NÃO
# 13              SERRA    29167-080          ES                 NÃO
# 14              SERRA    29167-080          ES                 NÃO
# 15              SERRA    29167-080          ES                 NÃO
#
#    OPERACAO_USUAL                                      EXIBIDOR
# 11      COMERCIAL  ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP  \
# 12      COMERCIAL  ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP
# 13      COMERCIAL  ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP
# 14      COMERCIAL  ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP
# 15      COMERCIAL  ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP
#
#    REGISTRO_EXIBIDOR       CNPJ_EXIBIDOR  SITUACAO_EXIBIDOR GRUPO_EXIBIDOR
# 11             13977  03.879.383/0001-08            REGULAR     CINESERCLA
# 12             13977  03.879.383/0001-08            REGULAR     CINESERCLA
# 13             13977  03.879.383/0001-08            REGULAR     CINESERCLA
# 14             13977  03.879.383/0001-08            REGULAR     CINESERCLA
# 15             13977  03.879.383/0001-08            REGULAR     CINESERCLA
#
# [5 rows x 22 columns]

# %%
df_salas_exib_es.columns
# Out:
# Index(['NOME_SALA', 'REGISTRO_SALA', 'CNPJ_SALA', 'SITUACAO_SALA',
#        'ASSENTOS_SALA', 'NOME_COMPLEXO', 'REGISTRO_COMPLEXO',
#        'PAGINA_ELETRONICA_COMPLEXO', 'ENDERECO_COMPLEXO',
#        'NUMERO_ENDERECO_COMPLEXO', 'COMPLEMENTO_COMPLEXO', 'BAIRRO_COMPLEXO',
#        'MUNICIPIO_COMPLEXO', 'CEP_COMPLEXO', 'UF_COMPLEXO',
#        'COMPLEXO_ITINERANTE', 'OPERACAO_USUAL', 'EXIBIDOR',
#        'REGISTRO_EXIBIDOR', 'CNPJ_EXIBIDOR', 'SITUACAO_EXIBIDOR',
#        'GRUPO_EXIBIDOR'],
#       dtype='object')

# %%
df_salas_exib_es_end = df_salas_exib_es[['ENDERECO_COMPLEXO',
       'NUMERO_ENDERECO_COMPLEXO', 'COMPLEMENTO_COMPLEXO', 'BAIRRO_COMPLEXO',
       'MUNICIPIO_COMPLEXO', 'CEP_COMPLEXO']]

df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'] = df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'].astype(str)

df_salas_exib_es_end['ENDERECO_COMPLETO'] = df_salas_exib_es_end['ENDERECO_COMPLEXO'] + ' ' + '- ' + \
                                            df_salas_exib_es_end['COMPLEMENTO_COMPLEXO'] + ' ' + '- N° ' + \
                                            df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'] + ' ' + '- ' + \
                                            df_salas_exib_es_end['BAIRRO_COMPLEXO'] + ' ' + '- CEP:' + \
                                            df_salas_exib_es_end['CEP_COMPLEXO'] + ' ' + '- ' + \
                                            df_salas_exib_es_end['MUNICIPIO_COMPLEXO']

dataframes_to_concat = [df_salas_exib_es, df_salas_exib_es_end[['ENDERECO_COMPLETO']]]

df_salas_exib_es = pd.concat(dataframes_to_concat, axis=1)

df_salas_exib_es
# Out:
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\1812274193.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'] = df_salas_exib_es_end['NUMERO_ENDERECO_COMPLEXO'].astype(str)
# C:\Users\syafo\AppData\Local\Temp\ipykernel_13132\1812274193.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salas_exib_es_end['ENDERECO_COMPLETO'] = df_salas_exib_es_end['ENDERECO_COMPLEXO'] + ' ' + '- ' + \
#                                    NOME_SALA  REGISTRO_SALA
# 11    CINESERCLA SHOPPING MONTSERRAT SALA 01        5004768  \
# 12    CINESERCLA SHOPPING MONTSERRAT SALA 02        5004764
# 13    CINESERCLA SHOPPING MONTSERRAT SALA 03        5004767
# 14    CINESERCLA SHOPPING MONTSERRAT SALA 04        5004765
# 15    CINESERCLA SHOPPING MONTSERRAT SALA 05        5004766
# ...                                      ...            ...
# 3656                         CINE METRÓPOLIS        5006071
# 3674                      AFA CINE UNIMED 01        5002629
# 3675                      AFA CINE UNIMED 02        5002630
# 3676                      AFA CINE UNIMED 03        5005912
# 3677                      AFA CINE UNIMED 04        5005913
#
#                CNPJ_SALA     SITUACAO_SALA  ASSENTOS_SALA
# 11    03.879.383/0005-31  EM FUNCIONAMENTO            225  \
# 12    03.879.383/0005-31  EM FUNCIONAMENTO            263
# 13    03.879.383/0005-31  EM FUNCIONAMENTO            159
# 14    03.879.383/0005-31  EM FUNCIONAMENTO            173
# 15    03.879.383/0005-31  EM FUNCIONAMENTO            157
# ...                  ...               ...            ...
# 3656  32.479.123/0001-43  EM FUNCIONAMENTO            240
# 3674  08.537.690/0001-24  EM FUNCIONAMENTO            178
# 3675  08.537.690/0001-24  EM FUNCIONAMENTO            299
# 3676  08.537.690/0001-24  EM FUNCIONAMENTO            275
# 3677  08.537.690/0001-24  EM FUNCIONAMENTO            142
#
#                        NOME_COMPLEXO  REGISTRO_COMPLEXO
# 11    CINESERCLA SHOPPING MONTSERRAT              27434  \
# 12    CINESERCLA SHOPPING MONTSERRAT              27434
# 13    CINESERCLA SHOPPING MONTSERRAT              27434
# 14    CINESERCLA SHOPPING MONTSERRAT              27434
# 15    CINESERCLA SHOPPING MONTSERRAT              27434
# ...                              ...                ...
# 3656                 CINE METRÓPOLIS              40544
# 3674                 AFA CINE UNIMED              17321
# 3675                 AFA CINE UNIMED              17321
# 3676                 AFA CINE UNIMED              17321
# 3677                 AFA CINE UNIMED              17321
#
#      PAGINA_ELETRONICA_COMPLEXO                ENDERECO_COMPLEXO
# 11               SEM INFORMAÇÃO  Avenida Eldes Scherrer de Souza  \
# 12               SEM INFORMAÇÃO  Avenida Eldes Scherrer de Souza
# 13               SEM INFORMAÇÃO  Avenida Eldes Scherrer de Souza
# 14               SEM INFORMAÇÃO  Avenida Eldes Scherrer de Souza
# 15               SEM INFORMAÇÃO  Avenida Eldes Scherrer de Souza
# ...                         ...                              ...
# 3656             cinema.ufes.br         Avenida Fernando Ferrari
# 3674             SEM INFORMAÇÃO   AV FRANCISCO LACERDA DE AGUIAR
# 3675             SEM INFORMAÇÃO   AV FRANCISCO LACERDA DE AGUIAR
# 3676             SEM INFORMAÇÃO   AV FRANCISCO LACERDA DE AGUIAR
# 3677             SEM INFORMAÇÃO   AV FRANCISCO LACERDA DE AGUIAR
#
#       NUMERO_ENDERECO_COMPLEXO  ... CEP_COMPLEXO UF_COMPLEXO
# 11                        2162  ...    29167-080          ES  \
# 12                        2162  ...    29167-080          ES
# 13                        2162  ...    29167-080          ES
# 14                        2162  ...    29167-080          ES
# 15                        2162  ...    29167-080          ES
# ...                        ...  ...          ...         ...
# 3656                       514  ...    29075-910          ES
# 3674                       382  ...    29303-384          ES
# 3675                       382  ...    29303-384          ES
# 3676                       382  ...    29303-384          ES
# 3677                       382  ...    29303-384          ES
#
#      COMPLEXO_ITINERANTE OPERACAO_USUAL
# 11                   NÃO      COMERCIAL  \
# 12                   NÃO      COMERCIAL
# 13                   NÃO      COMERCIAL
# 14                   NÃO      COMERCIAL
# 15                   NÃO      COMERCIAL
# ...                  ...            ...
# 3656                 NÃO  NÃO COMERCIAL
# 3674                 NÃO      COMERCIAL
# 3675                 NÃO      COMERCIAL
# 3676                 NÃO      COMERCIAL
# 3677                 NÃO      COMERCIAL
#
#                                           EXIBIDOR REGISTRO_EXIBIDOR
# 11    ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP             13977  \
# 12    ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP             13977
# 13    ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP             13977
# 14    ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP             13977
# 15    ADICINE ADMINISTRADORA DE CINEMAS EIRELI-EPP             13977
# ...                                            ...               ...
# 3656        UNIVERSIDADE FEDERAL DO ESPÍRITO SANTO             39885
# 3674                  VIA SUL CINEMATOGRÁFICA LTDA             12489
# 3675                  VIA SUL CINEMATOGRÁFICA LTDA             12489
# 3676                  VIA SUL CINEMATOGRÁFICA LTDA             12489
# 3677                  VIA SUL CINEMATOGRÁFICA LTDA             12489
#
#            CNPJ_EXIBIDOR SITUACAO_EXIBIDOR
# 11    03.879.383/0001-08           REGULAR  \
# 12    03.879.383/0001-08           REGULAR
# 13    03.879.383/0001-08           REGULAR
# 14    03.879.383/0001-08           REGULAR
# 15    03.879.383/0001-08           REGULAR
# ...                  ...               ...
# 3656  32.479.123/0001-43           REGULAR
# 3674  08.537.690/0001-24         IRREGULAR
# 3675  08.537.690/0001-24         IRREGULAR
# 3676  08.537.690/0001-24         IRREGULAR
# 3677  08.537.690/0001-24         IRREGULAR
#
#                             GRUPO_EXIBIDOR
# 11                              CINESERCLA  \
# 12                              CINESERCLA
# 13                              CINESERCLA
# 14                              CINESERCLA
# 15                              CINESERCLA
# ...                                    ...
# 3656  NAO PERTENCE A NENHUM GRUPO EXIBIDOR
# 3674                                   AFA
# 3675                                   AFA
# 3676                                   AFA
# 3677                                   AFA
#
#                                       ENDERECO_COMPLETO
# 11    Avenida Eldes Scherrer de Souza - loja 303 C -...
# 12    Avenida Eldes Scherrer de Souza - loja 303 C -...
# 13    Avenida Eldes Scherrer de Souza - loja 303 C -...
# 14    Avenida Eldes Scherrer de Souza - loja 303 C -...
# 15    Avenida Eldes Scherrer de Souza - loja 303 C -...
# ...                                                 ...
# 3656  Avenida Fernando Ferrari - Campus Univer - N° ...
# 3674  AV FRANCISCO LACERDA DE AGUIAR - SALA 1 A 4  -...
# 3675  AV FRANCISCO LACERDA DE AGUIAR - SALA 1 A 4  -...
# 3676  AV FRANCISCO LACERDA DE AGUIAR - SALA 1 A 4  -...
# 3677  AV FRANCISCO LACERDA DE AGUIAR - SALA 1 A 4  -...
#
# [76 rows x 23 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Criando Index em branco

# %%
# def blank_index(df):
#     blank_row_df = {}
#     blank_row = pd.DataFrame(blank_row_df, index=[0])
#     return pd.concat([df, blank_row], ignore_index=True)


# df_ag_econ_reg_es = blank_index(df_ag_econ_reg_es)
# df_proj_fsa_desemb_es = blank_index(df_proj_fsa_desemb_es)
# df_ativi_econ_agent_regis_es = blank_index(df_ativi_econ_agent_regis_es)
# df_proj_renun_fisc_es = blank_index(df_proj_renun_fisc_es)
# df_grupos_econ_es = blank_index(df_grupos_econ_es)
# df_salas_exib_es = blank_index(df_salas_exib_es)

# %% [markdown]
# ---

# %% [markdown]
# ### Adequação Power BI

# %%
#Projetos de Renúncia Fiscal
def replace(df, column):
    df[column] = df[column].astype(str)
    df[column] = df[column].str.replace('.', ',')
    return df

# replace(df_proj_renun_fisc_es, 'TOTAL_CAPTADO')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART1')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART1A')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART3')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART39')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'ART3A')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'FUNCINES')
# df_proj_renun_fisc_es = replace(df_proj_renun_fisc_es, 'LEI_8313')

# #-----------------------------------------------

#Projetos FSA e Desembolso

# replace(df_proj_fsa_desemb_es, 'VL_CONTRATO_DOU')
# replace(df_proj_fsa_desemb_es, 'VL_TOTAL_LIBERADO')

# #-----------------------------------------------

#Investidores Projetos Renúncia Fiscal

# replace(df_invest_proj_renun_fiscal, 'ART25')
# replace(df_invest_proj_renun_fiscal, 'ART18')
# replace(df_invest_proj_renun_fiscal, 'ART1A')
# replace(df_invest_proj_renun_fiscal, 'ART1')
# replace(df_invest_proj_renun_fiscal, 'ART39')
# replace(df_invest_proj_renun_fiscal, 'ART3A')
# replace(df_invest_proj_renun_fiscal, 'ART3')
# replace(df_invest_proj_renun_fiscal, 'ART41')
# replace(df_invest_proj_renun_fiscal, 'VL_TOTAL_INVESTIDO')

# %% [markdown]
# ---

# %% [markdown]
# ### Dataframe - Projetos

# %%
df_concat_proj_1 = df_proj_fsa_desemb_es[['VL_TOTAL_LIBERADO', 'CNPJ_PROPONENTE', 'TITULO_PROJETO', 'CHAMADA_PUBLICA']]
df_concat_proj_2 = df_proj_renun_fisc_es[['TOTAL_CAPTADO', 'CNPJ_PROPONENTE', 'TITULO_PROJETO']]

df_concat_proj_2 = df_concat_proj_2.rename(columns={'TOTAL_CAPTADO' : 'TOTAL_CAPTADO_RENUN', 'TITULO_PROJETO' : 'TITULO_PROJETO_RENUN' })
df_concat_proj_1 = df_concat_proj_1.rename(columns={'VL_TOTAL_LIBERADO' : 'VL_TOTAL_LIBERADO_FSA_DESEMB', 'TITULO_PROJETO' : 'TITULO_PROJETO_FSA_DESEMB'})

df_projetos_aprov_es = df_concat_proj_1.merge(df_concat_proj_2, on='CNPJ_PROPONENTE', how='outer')

def fillna(df, column):
    df[column].fillna(0.0, inplace=True)

fillna(df_projetos_aprov_es, 'TOTAL_CAPTADO_RENUN')
fillna(df_projetos_aprov_es, 'VL_TOTAL_LIBERADO_FSA_DESEMB')

df_projetos_aprov_es['SOMA_TOTAL_CAPTADO'] = df_projetos_aprov_es['TOTAL_CAPTADO_RENUN'] + df_projetos_aprov_es['VL_TOTAL_LIBERADO_FSA_DESEMB']
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=11)
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=3)
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=23)
df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'] = df_projetos_aprov_es['TITULO_PROJETO_FSA_DESEMB'].drop(index=24)

df_projetos_aprov_es
# Out:
#     VL_TOTAL_LIBERADO_FSA_DESEMB     CNPJ_PROPONENTE
# 0                       42692.10  10.763.360/0001-07  \
# 1                     1014000.00  14.210.788/0001-75
# 2                      900000.00  14.210.788/0001-75
# 3                      200000.01  02.616.581/0001-16
# 4                      300000.00  02.616.581/0001-16
# 5                      100000.00  04.585.783/0001-73
# 6                      160000.00  04.585.783/0001-73
# 7                      100000.00  04.585.783/0001-73
# 8                      999999.00  04.585.783/0001-73
# 9                      150000.00  08.103.899/0001-80
# 10                     180000.00  08.103.899/0001-80
# 11                     600000.00  18.589.962/0001-93
# 12                      88773.26  18.589.962/0001-93
# 13                     180000.00  21.710.727/0001-32
# 14                      21346.06  17.151.166/0001-01
# 15                      75000.00  18.580.137/0001-28
# 16                     180000.00  18.580.137/0001-28
# 17                      34153.69  04.769.554/0001-09
# 18                     350000.00  14.635.446/0001-05
# 19                          0.00  14.635.446/0001-05
# 20                          0.00  21.033.878/0001-01
# 21                     629061.00  09.369.796/0001-29
# 22                     600000.00  09.369.796/0001-29
# 23                    1100000.00  09.369.796/0001-29
# 24                     122100.00  09.369.796/0001-29
# 25                      21346.06  19.387.261/0001-34
# 26                     150000.00  14.128.876/0001-22
# 27                     500000.00  14.128.876/0001-22
# 28                     162000.00  21.681.140/0001-42
# 29                     175000.00  21.681.140/0001-42
# 30                      21346.06  31.703.432/0001-92
# 31                          0.00  05.077.549/0001-06
# 32                          0.00  05.077.549/0001-06
# 33                          0.00  01.592.538/0001-03
# 34                          0.00  31.478.621/0001-09
# 35                          0.00  31.478.621/0001-09
# 36                          0.00  36.300.499/0001-08
#
#                             TITULO_PROJETO_FSA_DESEMB
# 0                                                 NaN  \
# 1            HABITAÇÃO SOCIAL - PROJETOS DE UM BRASIL
# 2                               OS PRIMEIROS SOLDADOS
# 3                                                 NaN
# 4                   26º FESTIVAL DE CINEMA DE VITÓRIA
# 5   4º CINE.EMA - FESTIVAL DE CINEMA AMBIENTAL DO ...
# 6   7º FECIN - FESTIVAL DE TV E CINEMA DO INTERIOR...
# 7   O PALHAÇO MENINO - MEMÓRIAS DE UM MENINO MASCA...
# 8   PÁSSARO DE PAPEL - A JORNADA DE JAIMINHO E SUA...
# 9                                               DIDI
# 10                              TODA NOITE ESTAREI LÁ
# 11                                                NaN
# 12                                DESTINO DAS SOMBRAS
# 13                                             A SUGA
# 14                                                NaN
# 15                                  OS INCONTESTÁVEIS
# 16                                           PRESENÇA
# 17                                                NaN
# 18                                               ÁRIA
# 19                                           PALALOOS
# 20                                                NaN
# 21                                         MATA NEGRA
# 22                     O CEMITÉRIO DAS ALMAS PERDIDAS
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                   VIAGEM À XIBALBÁ
# 27                                    GAROTAS DO GAME
# 28                                       ZORA CURIOSA
# 29  FESTIVAL BESIDES THE SCREEN 2019 - INTELIGÊNCI...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                       CHAMADA_PUBLICA  TOTAL_CAPTADO_RENUN
# 0   PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                 0.00  \
# 1                                           PRODAV 11                 0.00
# 2                                  ARRANJOS REGIONAIS                 0.00
# 3                                            SAV/MINC            949827.59
# 4                                            SAV/MINC            949827.59
# 5                                            SAV/MINC                 0.00
# 6                                            SAV/MINC                 0.00
# 7                                            SAV/MINC                 0.00
# 8                                            SAV/MINC                 0.00
# 9                                  ARRANJOS REGIONAIS                 0.00
# 10                                 ARRANJOS REGIONAIS                 0.00
# 11                                 ARRANJOS REGIONAIS            550474.36
# 12                                          PRODECINE            550474.36
# 13                                 ARRANJOS REGIONAIS                 0.00
# 14  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                 0.00
# 15                                 ARRANJOS REGIONAIS                 0.00
# 16                                 ARRANJOS REGIONAIS                 0.00
# 17  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                 0.00
# 18                                           SAV/MINC                 0.00
# 19                                             PRODAV                 0.00
# 20  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                 0.00
# 21                                          PRODECINE                 0.00
# 22                                 ARRANJOS REGIONAIS                 0.00
# 23                                          PRODECINE                 0.00
# 24                          COMERCIALIZAÇÃO EM CINEMA                 0.00
# 25  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                 0.00
# 26                                             PRODAV                 0.00
# 27                                           SAV/MINC                 0.00
# 28                                          PRODAV 11                 0.00
# 29                                           SAV/MINC                 0.00
# 30  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                 0.00
# 31  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...                 0.00
# 32                            CRÉDITO EMERGENCIAL FSA                 0.00
# 33                                                NaN            484749.00
# 34                                                NaN            306500.00
# 35                                                NaN            188390.00
# 36                                                NaN            238550.00
#
#                                  TITULO_PROJETO_RENUN  SOMA_TOTAL_CAPTADO
# 0                                                 NaN            42692.10
# 1                                                 NaN          1014000.00
# 2                                                 NaN           900000.00
# 3                                        Outro Sertão          1149827.60
# 4                                        Outro Sertão          1249827.59
# 5                                                 NaN           100000.00
# 6                                                 NaN           160000.00
# 7                                                 NaN           100000.00
# 8                                                 NaN           999999.00
# 9                                                 NaN           150000.00
# 10                                                NaN           180000.00
# 11  A Incrível Jornada - A História das Baleias Ca...          1150474.36
# 12  A Incrível Jornada - A História das Baleias Ca...           639247.62
# 13                                                NaN           180000.00
# 14                                                NaN            21346.06
# 15                                                NaN            75000.00
# 16                                                NaN           180000.00
# 17                                                NaN            34153.69
# 18                                                NaN           350000.00
# 19                                                NaN                0.00
# 20                                                NaN                0.00
# 21                                                NaN           629061.00
# 22                                                NaN           600000.00
# 23                                                NaN          1100000.00
# 24                                                NaN           122100.00
# 25                                                NaN            21346.06
# 26                                                NaN           150000.00
# 27                                                NaN           500000.00
# 28                                                NaN           162000.00
# 29                                                NaN           175000.00
# 30                                                NaN            21346.06
# 31                                                NaN                0.00
# 32                                                NaN                0.00
# 33                                             HELENA           484749.00
# 34                                             Punhal           306500.00
# 35                        Morte da Mulata (A) - Filme           188390.00
# 36  A Rebelião dos Estudantes      (Ex - Rebelião ...           238550.00

# %%
#Dataframe de Títulos de Projeto
df_titulos_proj = df_projetos_aprov_es[['CNPJ_PROPONENTE', 'TITULO_PROJETO_FSA_DESEMB', 'TITULO_PROJETO_RENUN', 'CHAMADA_PUBLICA']]

def replace(df, column, row, new):
    df.at[row, column] = new

replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 3, 'Outro Sertão')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 11, 'A Incrível Jornada - A História das Baleias Capixabas')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 33, 'HELENA')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 34, 'Punhal')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 35, 'Morte da Mulata (A) - Filme')
replace(df_titulos_proj, 'TITULO_PROJETO_FSA_DESEMB', 36, 'A Rebelião dos Estudantes      (Ex - Rebelião dos Estudantes - Brasília, 1968 (A))')
replace(df_titulos_proj, 'CHAMADA_PUBLICA', 1, 'PRODAV')
replace(df_titulos_proj, 'CHAMADA_PUBLICA', 28, 'PRODAV')

df_titulos_proj = df_titulos_proj.drop(index=24)
df_titulos_proj = df_titulos_proj.drop(index=23)

df_titulos_proj = df_titulos_proj.rename(columns={'TITULO_PROJETO_FSA_DESEMB' : 'TITULO_PROJETOS_APROVADOS'})
df_titulos_proj = df_titulos_proj[['CNPJ_PROPONENTE', 'TITULO_PROJETOS_APROVADOS', 'CHAMADA_PUBLICA']]

df_titulos_proj['TITULO_PROJETOS_APROVADOS'] = df_titulos_proj['TITULO_PROJETOS_APROVADOS'].fillna(df_titulos_proj['CHAMADA_PUBLICA'][0])


df_titulos_proj
# Out:
#        CNPJ_PROPONENTE                          TITULO_PROJETOS_APROVADOS
# 0   10.763.360/0001-07  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...  \
# 1   14.210.788/0001-75           HABITAÇÃO SOCIAL - PROJETOS DE UM BRASIL
# 2   14.210.788/0001-75                              OS PRIMEIROS SOLDADOS
# 3   02.616.581/0001-16                                       Outro Sertão
# 4   02.616.581/0001-16                  26º FESTIVAL DE CINEMA DE VITÓRIA
# 5   04.585.783/0001-73  4º CINE.EMA - FESTIVAL DE CINEMA AMBIENTAL DO ...
# 6   04.585.783/0001-73  7º FECIN - FESTIVAL DE TV E CINEMA DO INTERIOR...
# 7   04.585.783/0001-73  O PALHAÇO MENINO - MEMÓRIAS DE UM MENINO MASCA...
# 8   04.585.783/0001-73  PÁSSARO DE PAPEL - A JORNADA DE JAIMINHO E SUA...
# 9   08.103.899/0001-80                                              DIDI
# 10  08.103.899/0001-80                              TODA NOITE ESTAREI LÁ
# 11  18.589.962/0001-93  A Incrível Jornada - A História das Baleias Ca...
# 12  18.589.962/0001-93                                DESTINO DAS SOMBRAS
# 13  21.710.727/0001-32                                             A SUGA
# 14  17.151.166/0001-01  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 15  18.580.137/0001-28                                  OS INCONTESTÁVEIS
# 16  18.580.137/0001-28                                           PRESENÇA
# 17  04.769.554/0001-09  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 18  14.635.446/0001-05                                               ÁRIA
# 19  14.635.446/0001-05                                           PALALOOS
# 20  21.033.878/0001-01  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 21  09.369.796/0001-29                                         MATA NEGRA
# 22  09.369.796/0001-29                     O CEMITÉRIO DAS ALMAS PERDIDAS
# 25  19.387.261/0001-34  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 26  14.128.876/0001-22                                   VIAGEM À XIBALBÁ
# 27  14.128.876/0001-22                                    GAROTAS DO GAME
# 28  21.681.140/0001-42                                       ZORA CURIOSA
# 29  21.681.140/0001-42  FESTIVAL BESIDES THE SCREEN 2019 - INTELIGÊNCI...
# 30  31.703.432/0001-92  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 31  05.077.549/0001-06  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 32  05.077.549/0001-06  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 33  01.592.538/0001-03                                             HELENA
# 34  31.478.621/0001-09                                             Punhal
# 35  31.478.621/0001-09                        Morte da Mulata (A) - Filme
# 36  36.300.499/0001-08  A Rebelião dos Estudantes      (Ex - Rebelião ...
#
#                                       CHAMADA_PUBLICA
# 0   PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 1                                              PRODAV
# 2                                  ARRANJOS REGIONAIS
# 3                                            SAV/MINC
# 4                                            SAV/MINC
# 5                                            SAV/MINC
# 6                                            SAV/MINC
# 7                                            SAV/MINC
# 8                                            SAV/MINC
# 9                                  ARRANJOS REGIONAIS
# 10                                 ARRANJOS REGIONAIS
# 11                                 ARRANJOS REGIONAIS
# 12                                          PRODECINE
# 13                                 ARRANJOS REGIONAIS
# 14  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 15                                 ARRANJOS REGIONAIS
# 16                                 ARRANJOS REGIONAIS
# 17  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 18                                           SAV/MINC
# 19                                             PRODAV
# 20  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 21                                          PRODECINE
# 22                                 ARRANJOS REGIONAIS
# 25  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 26                                             PRODAV
# 27                                           SAV/MINC
# 28                                             PRODAV
# 29                                           SAV/MINC
# 30  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 31  PROGRAMA ESPECIAL DE APOIO AO PEQUENO EXIBIDOR...
# 32                            CRÉDITO EMERGENCIAL FSA
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN

# %% [markdown]
# ---

# %% [markdown]
# ### Export

# %%
def export(df, file):
    df.to_csv(file, index=False, encoding='utf-8', sep=',')

# Export para Test
#export(df, 'arquivo_teste.csv')

# export(df_ag_econ_reg_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_AgentesEconomicosRegulares.csv')
# export(df_proj_fsa_desemb_es , 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_ProjetosContratadosFSAeDesembolso.csv')
#export(df_proj_renun_fisc_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_ProjetosRenunciaFiscal.csv')
# export(df_ativi_econ_agent_regis_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_AtividadesEconomicasDosAgentesRegistrados.csv')
# export(df_grupos_econ_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_GruposEconomicos.csv')
export(df_salas_exib_es, 'C:\\Users\\syafo\\OneDrive\\Documentos\\GitHub\\Ancine\\EDA\\Ancine_ES\\Export\\ES_SalasDeExibicaoEComplexos.csv')

#Dataframe Projetos
# export(df_projetos_aprov_es, 'ProjetosAprovados.csv')
# export(df_titulos_proj, 'TitulosProjetos.csv')
